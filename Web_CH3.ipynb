# %% [markdown]
# # 크롤링 시작하기
# http://en.wikipedia.org/wiki/Kevin_Bacon
#
#
# ### 위키백과의 여섯 다리를 푸는 프로젝트
# #### 단일 도메인 내의 이동 (링크에서 링크로 움직이며 웹사이트를 무작위로 이동)

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://en.wikipedia.org/wiki/Kevin_Bacon")
bs0bj = BeautifulSoup(html, "html.parser")
for link in bs0bj.findAll("a"):
    if 'href' in link.attrs:
        print(link.attrs['href'])
        # href : 링크 소스
# Out:
# /wiki/Wikipedia:Protection_policy#semi
# #mw-head
# #p-search
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/File:Kevin_Bacon_SDCC_2014.jpg
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# #cite_note-1
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# http://baconbros.com/
# #cite_note-2
# #cite_note-actor-3
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# #cite_note-4
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-5
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# #cite_note-walk-6
# #Early_life_and_education
# #Acting_career
# #Early_work
# #1980s
# #1990s
# #2000s
# #2010s
# #Advertising_work
# #Personal_life
# #Six_Degrees_of_Kevin_Bacon
# #Music
# #Awards_and_nominations
# #Honors
# #Accolades
# #Filmography
# #See_also
# #References
# #External_links
# /wiki/Philadelphia
# #cite_note-actor-3
# #cite_note-actor-3
# /wiki/Edmund_Bacon_(architect)
# #cite_note-bacon-7
# /wiki/Julia_R._Masterman_High_School
# #cite_note-8
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# #cite_note-9
# /wiki/Glory_Van_Scott
# #cite_note-walk-6
# #cite_note-bacon-7
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# #cite_note-cosmo91-10
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# #cite_note-bacon-7
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# #cite_note-11
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# #cite_note-bio-12
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# #cite_note-kevin-13
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# #cite_note-14
# /wiki/Footloose_(1984_film)
# #cite_note-bio-12
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# #cite_note-time84-15
# #cite_note-bacon-7
# #cite_note-16
# #cite_note-17
# /wiki/People_(American_magazine)
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# #cite_note-bio-12
# /wiki/The_Big_Picture_(1989_film)
# #cite_note-18
# /wiki/Tremors_(film)
# #cite_note-19
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# #cite_note-bio-12
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# #cite_note-bio-12
# /wiki/The_New_York_Times
# #cite_note-nyt94-20
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# #cite_note-21
# /wiki/A_Few_Good_Men_(film)
# #cite_note-22
# /wiki/Michael_Greif
# #cite_note-bio-12
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# #cite_note-bio-12
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# #cite_note-bio-12
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# #cite_note-23
# /wiki/Sleepers_(film)
# #cite_note-24
# /wiki/Picture_Perfect_(1997_film)
# #cite_note-bio-12
# /wiki/Losing_Chase
# #cite_note-austin-25
# /wiki/Digging_to_China
# #cite_note-bio-12
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# #cite_note-bio-12
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# #cite_note-26
# /wiki/File:KevinBaconTakingChanceFeb09.jpg
# /wiki/File:KevinBaconTakingChanceFeb09.jpg
# /wiki/Taking_Chance
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# #cite_note-27
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# #cite_note-28
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# #cite_note-29
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/Pedophile
# /wiki/The_Woodsman_(2004_film)
# #cite_note-30
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# #cite_note-31
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Matthew_Vaughn
# /wiki/X-Men:_First_Class
# #cite_note-32
# /wiki/Sebastian_Shaw_(comics)
# #cite_note-33
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# #cite_note-8_the_play-34
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# #cite_note-8_play_video-35
# #cite_note-36
# /wiki/The_Following
# #cite_note-37
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# #cite_note-38
# /wiki/Huffington_Post
# #cite_note-39
# /wiki/Tremors_(film)
# /wiki/Wikipedia:Citation_needed
# /wiki/Tremors_5:_Bloodline
# /wiki/EE_(telecommunications_company)
# /wiki/United_Kingdom
# #cite_note-40
# #cite_note-41
# /wiki/Egg_as_food
# #cite_note-42
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# #cite_note-cosmo91-10
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# #cite_note-43
# /wiki/Tracy_Pollan
# #cite_note-44
# #cite_note-45
# #cite_note-46
# /wiki/The_Times
# #cite_note-47
# #cite_note-48
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# #cite_note-financialpost-49
# #cite_note-50
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# #cite_note-51
# #cite_note-52
# #cite_note-53
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# #cite_note-54
# /wiki/Bacon_number
# /wiki/Internet_Movie_Database
# #cite_note-55
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Bacon_number
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# #cite_note-56
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Music_album
# #cite_note-57
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Citing_sources
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:Reliable_sources
# //www.google.com/search?as_eq=wikipedia&q=%22Kevin+Bacon%22
# //www.google.com/search?tbm=nws&q=%22Kevin+Bacon%22+-wikipedia
# //www.google.com/search?&q=%22Kevin+Bacon%22+site:news.google.com/newspapers&source=newspapers
# //www.google.com/search?tbs=bks:1&q=%22Kevin+Bacon%22+-wikipedia
# //scholar.google.com/scholar?q=%22Kevin+Bacon%22
# https://www.jstor.org/action/doBasicSearch?Query=%22Kevin+Bacon%22&acc=on&wc=on
# /wiki/Help:Maintenance_template_removal
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/File:Kevin_Bacon%27s_Star_Walk_of_Fame.jpg
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# #cite_note-58
# /wiki/Denver_Film_Festival
# #cite_note-59
# /wiki/Phoenix_Film_Festival
# #cite_note-60
# /wiki/Santa_Barbara_International_Film_Festival
# #cite_note-61
# /wiki/Broadcast_Film_Critics_Association
# #cite_note-62
# /wiki/Seattle_International_Film_Festival
# #cite_note-63
# #cite_note-64
# /wiki/Apollo_13_(film)
# #cite_note-65
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# #cite_note-66
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# #cite_note-67
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Gold_Derby_Awards
# /wiki/Gold_Derby_Awards
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/X-Men:_First_Class
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/X-Men:_First_Class
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Kevin_Bacon_filmography
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# #cite_ref-1
# http://www.geneall.net/U/per_page.php?id=1014399
# #cite_ref-2
# https://web.archive.org/web/20090113222205/http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# http://www.newenglandancestors.org/research/services/articles_gbr78.asp
# #cite_ref-actor_3-0
# #cite_ref-actor_3-1
# #cite_ref-actor_3-2
# http://www.biography.com/people/kevin-bacon-9542173
# #cite_ref-4
# https://www.theguardian.com/film/filmblog/2009/feb/19/best-actors-never-nominated-for-oscars
# #cite_ref-5
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-walk_6-0
# #cite_ref-walk_6-1
# https://web.archive.org/web/20141016202657/http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# http://www.thebiographychannel.co.uk/biographies/kevin-bacon.html
# #cite_ref-bacon_7-0
# #cite_ref-bacon_7-1
# #cite_ref-bacon_7-2
# #cite_ref-bacon_7-3
# http://www.biography.com/news/kevin-bacon-biography-facts
# #cite_ref-8
# https://philadelphia.cbslocal.com/top-lists/stars-from-philly-to-hollywood/
# #cite_ref-9
# https://movies.yahoo.com/person/kevin-bacon/biography.html
# #cite_ref-cosmo91_10-0
# #cite_ref-cosmo91_10-1
# #cite_ref-11
# http://www.nydailynews.com/entertainment/happy-halloween-superstars-start-horror-flick-gallery-1.98345
# #cite_ref-bio_12-0
# #cite_ref-bio_12-1
# #cite_ref-bio_12-2
# #cite_ref-bio_12-3
# #cite_ref-bio_12-4
# #cite_ref-bio_12-5
# #cite_ref-bio_12-6
# #cite_ref-bio_12-7
# #cite_ref-bio_12-8
# #cite_ref-bio_12-9
# #cite_ref-bio_12-10
# https://www.pbs.org/wnet/finding-your-roots/profiles/kevin-bacon%C2%A0/
# #cite_ref-kevin_13-0
# http://www.tvguide.com/celebrities/kevin-bacon/bio/160550
# #cite_ref-14
# https://web.archive.org/web/20141021030336/http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# http://news.moviefone.com/2012/03/02/diner-30th-anniversary/
# #cite_ref-time84_15-0
# http://www.time.com/time/magazine/article/0,9171,950019,00.html
# #cite_ref-16
# http://www.huffingtonpost.com/2014/08/25/kevin-bacon-footloose_n_5710413.html
# #cite_ref-17
# https://web.archive.org/web/20090109152125/http://www.thebiographychannel.co.uk/biography_story/522%3A492/1/Kevin_Bacon.htm
# http://www.thebiographychannel.co.uk/biography_story/522:492/1/Kevin_Bacon.htm
# #cite_ref-18
# https://www.nytimes.com/1994/09/25/movies/a-second-wind-is-blowing-for-kevin-bacon.html
# #cite_ref-19
# https://www.nytimes.com/movie/review?res=9C0CE2DE1631F93AA25752C0A966958260
# #cite_ref-nyt94_20-0
# https://query.nytimes.com/gst/fullpage.html?res=9C07E6D91F3BF936A1575AC0A962958260
# #cite_ref-21
# http://www.jfk-online.com/jfkbacon.html
# #cite_ref-22
# http://www.tcm.com/this-month/article/143158%7C0/A-Few-Good-Men.html
# #cite_ref-23
# http://collider.com/kevin-bacon-commercials-footloose/
# #cite_ref-24
# http://www.rogerebert.com/reviews/sleepers-1996
# #cite_ref-austin_25-0
# http://www.austinchronicle.com/calendar/film/1997-02-07/283342/
# /wiki/The_Austin_Chronicle
# #cite_ref-26
# http://www.criminalelement.com/blogs/2013/09/under-the-raderhorror-movies-you-may-have-missed-stir-of-echoes
# #cite_ref-27
# http://www.rogerebert.com/reviews/hollow-man-2000
# #cite_ref-28
# https://web.archive.org/web/20141017080013/http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# http://movies.about.com/od/wherethetruthlies/a/truthkb101305.htm
# #cite_ref-29
# https://archive.is/20120604150801/http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# http://jam.canoe.ca/Movies/2005/09/14/1216527.html
# #cite_ref-30
# http://www.latimes.com/entertainment/la-et-kevin-bacon-photo6-photo.html
# #cite_ref-31
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-chance-body-fallen-marine-home-article-1.392226
# #cite_ref-32
# https://web.archive.org/web/20100722010545/http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# http://heatvision.hollywoodreporter.com/2010/07/winters-bone-star-cast-as-mystique-in-xmen-first-class.html
# #cite_ref-33
# https://web.archive.org/web/20100720060214/http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# http://www.forcesofgeek.com/2010/07/kevin-bacon-playing-sebastian-shaw-in-x.html
# #cite_ref-8_the_play_34-0
# http://www.accesshollywood.com/jesse-tyler-ferguson/glee-stars-touched-by-brad-pitt-and-george-clooneys-support-of-8_article_61543
# /wiki/Access_Hollywood
# #cite_ref-8_play_video_35-0
# https://www.youtube.com/watch?v=qlUG8F9uVgM
# #cite_ref-36
# http://www.pinknews.co.uk/2012/03/01/youtube-to-broadcast-proposition-8-play-live/
# #cite_ref-37
# http://www.fox.com/the-following/
# #cite_ref-38
# https://news.yahoo.com/blogs/trending-now/kevin-bacon-gives-millennials-a-history-lesson-about-the--80s-162525915.html
# #cite_ref-39
# http://www.huffingtonpost.com.au/entry/kevin-bacon-tremors-tv-reboot_us_5655b651e4b072e9d1c13a11
# #cite_ref-40
# http://www.campaignlive.co.uk/news/1294856/
# #cite_ref-41
# http://parade.condenast.com/269380/ashleighschmitz/kevin-bacon-reprises-his-most-iconic-film-roles-in-british-commercial/
# #cite_ref-42
# http://money.cnn.com/2015/03/13/media/kevin-bacon-eggs/index.html
# #cite_ref-43
# http://www.nydailynews.com/entertainment/tv-movies/kevin-bacon-loyalty-nyc-philly-origins-peace-bustling-city-article-1.147197
# #cite_ref-44
# http://www.people.com/people/archive/article/0,,20093025,00.html
# #cite_ref-45
# https://web.archive.org/web/20141023014658/https://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# http://www.au.org/media/church-and-state/archives/2008/05/two-thumbs-up.html
# #cite_ref-46
# https://www.washingtonpost.com/wp-dyn/content/article/2008/03/25/AR2008032503852.html
# #cite_ref-47
# #cite_ref-48
# http://www.foxnews.com/story/0,2933,343589,00.html
# #cite_ref-financialpost_49-0
# https://web.archive.org/web/20140314085857/http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# http://economiccrisis.us/2009/06/may-god-spare-mercy-victim-tells-madoff/
# #cite_ref-50
# #cite_ref-51
# http://www.huffingtonpost.com/megan-smolenyak-smolenyak/6-degrees-of-separation-k_b_900707.html
# #cite_ref-52
# https://web.archive.org/web/20130405182304/http://www.drawtheline.org/watch-stuff/
# http://www.drawtheline.org/watch-stuff
# #cite_ref-53
# http://www.drawtheline.org/sign-now/
# #cite_ref-54
# http://www.sixdegrees.org/
# #cite_ref-55
# http://www.webmonkey.com/2012/09/easter-egg-google-connects-the-dots-for-bacon-number-search/
# #cite_ref-56
# https://www.telegraph.co.uk/science/science-news/4768389/And-the-winner-tonight-is.html
# #cite_ref-57
# http://baconbros.com/
# #cite_ref-58
# http://www.walkoffame.com/kevin-bacon
# #cite_ref-59
# https://www.imdb.com/event/ev0000209/2004/1/
# #cite_ref-60
# https://www.imdb.com/event/ev0000536/2005/1/
# #cite_ref-61
# https://www.imdb.com/event/ev0000589/2005/1/
# #cite_ref-62
# http://www.criticschoice.com/movie-awards/critics%E2%80%99-choice-movie-awards-winners-archive/
# #cite_ref-63
# https://www.imdb.com/event/ev0000600/2015/1/
# #cite_ref-64
# http://www.awardscircuit.com/2015/07/01/pixars-toy-story-wins-top-prize-for-1995-awards-circuit-community-awards/
# #cite_ref-65
# http://www.awardscircuit.com/acca/the-acca-nominations-2003/
# #cite_ref-66
# https://idobi.com/news/nsync-takes-home-three-blockbuster-entertainment-awards/
# #cite_ref-67
# https://www.upi.com/Boston-critics-pick-Mystic-River/24961071506935/
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# https://www.imdb.com/name/nm0000102/
# /wiki/IMDb
# https://www.ibdb.com/broadway-cast-staff/90569
# /wiki/Internet_Broadway_Database
# https://www.wikidata.org/wiki/Q3454165#P1220
# http://www.lortel.org/Archives/CreditableEntity/5597
# /wiki/Lortel_Archives
# https://www.allmovie.com/artist/p3164
# /wiki/AllMovie
# http://oracleofbacon.org
# /wiki/Template:Kevin_Bacon
# /wiki/Template_talk:Kevin_Bacon
# https://en.wikipedia.org/w/index.php?title=Template:Kevin_Bacon&action=edit
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Template:Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Template_talk:Critics%27_Choice_Movie_Award_for_Best_Actor
# https://en.wikipedia.org/w/index.php?title=Template:Critics%27_Choice_Movie_Award_for_Best_Actor&action=edit
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Template:GoldenGlobeBestActorTVMiniseriesFilm
# /wiki/Template_talk:GoldenGlobeBestActorTVMiniseriesFilm
# https://en.wikipedia.org/w/index.php?title=Template:GoldenGlobeBestActorTVMiniseriesFilm&action=edit
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Template:Saturn_Award_for_Best_Actor_on_Television
# /wiki/Template_talk:Saturn_Award_for_Best_Actor_on_Television
# https://en.wikipedia.org/w/index.php?title=Template:Saturn_Award_for_Best_Actor_on_Television&action=edit
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# /wiki/Template_talk:ScreenActorsGuildAward_MaleTVMiniseriesMovie
# https://en.wikipedia.org/w/index.php?title=Template:ScreenActorsGuildAward_MaleTVMiniseriesMovie&action=edit
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Help:Authority_control
# https://www.wikidata.org/wiki/Q3454165
# /wiki/Bibsys
# https://authority.bibsys.no/authority/rest/authorities/html/98015093
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1298810
# /wiki/Biblioth%C3%A8que_nationale_de_France
# https://catalogue.bnf.fr/ark:/12148/cb139817766
# https://data.bnf.fr/ark:/12148/cb139817766
# /wiki/Integrated_Authority_File
# https://d-nb.info/gnd/124109659
# /wiki/International_Standard_Name_Identifier
# http://isni.org/isni/0000000121291300
# /wiki/Library_of_Congress_Control_Number
# https://id.loc.gov/authorities/names/n88034930
# /wiki/National_Library_of_Latvia
# https://kopkatalogs.lv/F?func=direct&local_base=lnc10&doc_number=000249798&P_CON_LNG=ENG
# /wiki/MusicBrainz
# https://musicbrainz.org/artist/cc0dbdfc-9b2c-4e31-8448-808412388406
# /wiki/National_Library_of_the_Czech_Republic
# https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=xx0025279&CON_LNG=ENG
# /wiki/National_Library_of_Australia
# https://nla.gov.au/anbd.aut-an36021861
# /wiki/National_Library_of_Australia
# https://trove.nla.gov.au/people/1189569
# /wiki/National_Library_of_Israel
# http://aleph.nli.org.il/F/?func=find-b&local_base=NNL10&find_code=SYS&con_lng=eng&request=002168993
# /wiki/National_Library_of_Poland
# https://tools.wmflabs.org/wikidata-externalid-url?p=1695&id=A1257000X
# /wiki/Royal_Library_of_the_Netherlands
# http://data.bibliotheken.nl/id/thes/p147880998
# /wiki/RERO_(Library_Network_of_Western_Switzerland)
# http://data.rero.ch/02-A016294166
# /wiki/SNAC
# http://socialarchive.iath.virginia.edu/ark:/99166/w6w67gw2
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# https://www.idref.fr/084292652
# /wiki/Virtual_International_Authority_File
# https://viaf.org/viaf/39570812
# /wiki/WorldCat_Identities
# https://www.worldcat.org/identities/containsVIAFID/39570812
# https://en.wikipedia.org/w/index.php?title=Kevin_Bacon&oldid=915548116
# /wiki/Help:Category
# /wiki/Category:1958_births
# /wiki/Category:20th-century_American_male_actors
# /wiki/Category:21st-century_American_male_actors
# /wiki/Category:American_atheists
# /wiki/Category:American_male_film_actors
# /wiki/Category:American_male_soap_opera_actors
# /wiki/Category:American_male_television_actors
# /wiki/Category:American_male_voice_actors
# /wiki/Category:The_Bacon_Brothers_members
# /wiki/Category:Best_Miniseries_or_Television_Movie_Actor_Golden_Globe_winners
# /wiki/Category:Circle_in_the_Square_Theatre_School_alumni
# /wiki/Category:Living_people
# /wiki/Category:Male_actors_from_Philadelphia
# /wiki/Category:Obie_Award_recipients
# /wiki/Category:Outstanding_Performance_by_a_Cast_in_a_Motion_Picture_Screen_Actors_Guild_Award_winners
# /wiki/Category:Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie_Screen_Actors_Guild_Award_winners
# /wiki/Category:Sedgwick_family
# /wiki/Category:People_from_the_Upper_West_Side
# /wiki/Category:Articles_with_short_description
# /wiki/Category:Wikipedia_indefinitely_semi-protected_biographies_of_living_people
# /wiki/Category:Use_mdy_dates_from_October_2016
# /wiki/Category:Articles_with_hCards
# /wiki/Category:All_articles_with_unsourced_statements
# /wiki/Category:Articles_with_unsourced_statements_from_January_2016
# /wiki/Category:BLP_articles_lacking_sources_from_October_2017
# /wiki/Category:All_BLP_articles_lacking_sources
# /wiki/Category:Commons_category_link_from_Wikidata
# /wiki/Category:Articles_with_IBDb_links
# /wiki/Category:Internet_Off-Broadway_Database_person_ID_same_as_Wikidata
# /wiki/Category:Wikipedia_articles_with_BIBSYS_identifiers
# /wiki/Category:Wikipedia_articles_with_BNE_identifiers
# /wiki/Category:Wikipedia_articles_with_BNF_identifiers
# /wiki/Category:Wikipedia_articles_with_GND_identifiers
# /wiki/Category:Wikipedia_articles_with_ISNI_identifiers
# /wiki/Category:Wikipedia_articles_with_LCCN_identifiers
# /wiki/Category:Wikipedia_articles_with_LNB_identifiers
# /wiki/Category:Wikipedia_articles_with_MusicBrainz_identifiers
# /wiki/Category:Wikipedia_articles_with_NKC_identifiers
# /wiki/Category:Wikipedia_articles_with_NLA_identifiers
# /wiki/Category:Wikipedia_articles_with_NLA-person_identifiers
# /wiki/Category:Wikipedia_articles_with_NLI_identifiers
# /wiki/Category:Wikipedia_articles_with_NLP_identifiers
# /wiki/Category:Wikipedia_articles_with_NTA_identifiers
# /wiki/Category:Wikipedia_articles_with_RERO_identifiers
# /wiki/Category:Wikipedia_articles_with_SNAC-ID_identifiers
# /wiki/Category:Wikipedia_articles_with_SUDOC_identifiers
# /wiki/Category:Wikipedia_articles_with_VIAF_identifiers
# /wiki/Category:Wikipedia_articles_with_WorldCat-VIAF_identifiers
# /wiki/Special:MyTalk
# /wiki/Special:MyContributions
# /w/index.php?title=Special:CreateAccount&returnto=Kevin+Bacon
# /w/index.php?title=Special:UserLogin&returnto=Kevin+Bacon
# /wiki/Kevin_Bacon
# /wiki/Talk:Kevin_Bacon
# /wiki/Kevin_Bacon
# /w/index.php?title=Kevin_Bacon&action=edit
# /w/index.php?title=Kevin_Bacon&action=history
# /wiki/Main_Page
# /wiki/Main_Page
# /wiki/Portal:Contents
# /wiki/Portal:Featured_content
# /wiki/Portal:Current_events
# /wiki/Special:Random
# https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# //shop.wikimedia.org
# /wiki/Help:Contents
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Special:WhatLinksHere/Kevin_Bacon
# /wiki/Special:RecentChangesLinked/Kevin_Bacon
# /wiki/Wikipedia:File_Upload_Wizard
# /wiki/Special:SpecialPages
# /w/index.php?title=Kevin_Bacon&oldid=915548116
# /w/index.php?title=Kevin_Bacon&action=info
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165
# /w/index.php?title=Special:CiteThisPage&page=Kevin_Bacon&id=915548116
# https://commons.wikimedia.org/wiki/Category:Kevin_Bacon
# /w/index.php?title=Special:Book&bookcmd=book_creator&referer=Kevin+Bacon
# /w/index.php?title=Special:ElectronPdf&page=Kevin+Bacon&action=show-download-screen
# /w/index.php?title=Kevin_Bacon&printable=yes
# https://af.wikipedia.org/wiki/Kevin_Bacon
# https://ar.wikipedia.org/wiki/%D9%83%D9%8A%D9%81%D9%8A%D9%86_%D8%A8%D9%8A%D9%83%D9%86
# https://an.wikipedia.org/wiki/Kevin_Bacon
# https://ast.wikipedia.org/wiki/Kevin_Bacon
# https://azb.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://zh-min-nan.wikipedia.org/wiki/Kevin_Bacon
# https://bi.wikipedia.org/wiki/Kevin_Bacon
# https://bg.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D1%8A%D0%BD
# https://bs.wikipedia.org/wiki/Kevin_Bacon
# https://ca.wikipedia.org/wiki/Kevin_Bacon
# https://cs.wikipedia.org/wiki/Kevin_Bacon
# https://da.wikipedia.org/wiki/Kevin_Bacon
# https://de.wikipedia.org/wiki/Kevin_Bacon
# https://el.wikipedia.org/wiki/%CE%9A%CE%AD%CE%B2%CE%B9%CE%BD_%CE%9C%CF%80%CE%AD%CE%B9%CE%BA%CE%BF%CE%BD
# https://eml.wikipedia.org/wiki/Kevin_Bacon
# https://es.wikipedia.org/wiki/Kevin_Bacon
# https://eu.wikipedia.org/wiki/Kevin_Bacon
# https://fa.wikipedia.org/wiki/%DA%A9%D9%88%DB%8C%D9%86_%D8%A8%DB%8C%DA%A9%D9%86
# https://fr.wikipedia.org/wiki/Kevin_Bacon
# https://ga.wikipedia.org/wiki/Kevin_Bacon
# https://gl.wikipedia.org/wiki/Kevin_Bacon
# https://ko.wikipedia.org/wiki/%EC%BC%80%EB%B9%88_%EB%B2%A0%EC%9D%B4%EC%BB%A8
# https://hy.wikipedia.org/wiki/%D5%94%D6%87%D5%AB%D5%B6_%D4%B2%D5%A5%D5%B5%D6%84%D5%B8%D5%B6
# https://hr.wikipedia.org/wiki/Kevin_Bacon
# https://io.wikipedia.org/wiki/Kevin_Bacon
# https://id.wikipedia.org/wiki/Kevin_Bacon
# https://it.wikipedia.org/wiki/Kevin_Bacon
# https://he.wikipedia.org/wiki/%D7%A7%D7%95%D7%95%D7%99%D7%9F_%D7%91%D7%99%D7%99%D7%A7%D7%95%D7%9F
# https://ka.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://kk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://lv.wikipedia.org/wiki/Kevins_B%C4%93kons
# https://hu.wikipedia.org/wiki/Kevin_Bacon
# https://xmf.wikipedia.org/wiki/%E1%83%99%E1%83%94%E1%83%95%E1%83%98%E1%83%9C_%E1%83%91%E1%83%94%E1%83%98%E1%83%99%E1%83%9D%E1%83%9C%E1%83%98
# https://mn.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D1%8D%D0%B9%D0%BA%D0%BE%D0%BD
# https://nl.wikipedia.org/wiki/Kevin_Bacon
# https://ja.wikipedia.org/wiki/%E3%82%B1%E3%83%B4%E3%82%A3%E3%83%B3%E3%83%BB%E3%83%99%E3%83%BC%E3%82%B3%E3%83%B3
# https://no.wikipedia.org/wiki/Kevin_Bacon
# https://oc.wikipedia.org/wiki/Kevin_Bacon
# https://pl.wikipedia.org/wiki/Kevin_Bacon
# https://pt.wikipedia.org/wiki/Kevin_Bacon
# https://ro.wikipedia.org/wiki/Kevin_Bacon
# https://ru.wikipedia.org/wiki/%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD,_%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD
# https://sco.wikipedia.org/wiki/Kevin_Bacon
# https://simple.wikipedia.org/wiki/Kevin_Bacon
# https://sk.wikipedia.org/wiki/Kevin_Bacon
# https://ckb.wikipedia.org/wiki/%DA%A9%DB%8E%DA%A4%D9%86_%D8%A8%DB%95%DB%8C%DA%A9%D9%86
# https://sr.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D0%B8%D0%BD_%D0%91%D0%B5%D1%98%D0%BA%D0%BE%D0%BD
# https://sh.wikipedia.org/wiki/Kevin_Bacon
# https://fi.wikipedia.org/wiki/Kevin_Bacon
# https://sv.wikipedia.org/wiki/Kevin_Bacon
# https://th.wikipedia.org/wiki/%E0%B9%80%E0%B8%84%E0%B8%A7%E0%B8%B4%E0%B8%99_%E0%B9%80%E0%B8%9A%E0%B8%84%E0%B8%AD%E0%B8%99
# https://tr.wikipedia.org/wiki/Kevin_Bacon
# https://uk.wikipedia.org/wiki/%D0%9A%D0%B5%D0%B2%D1%96%D0%BD_%D0%91%D0%B5%D0%B9%D0%BA%D0%BE%D0%BD
# https://vi.wikipedia.org/wiki/Kevin_Bacon
# https://zh.wikipedia.org/wiki/%E5%87%AF%E6%96%87%C2%B7%E8%B4%9D%E8%82%AF
# https://www.wikidata.org/wiki/Special:EntityPage/Q3454165#sitelinks-wikipedia
# //en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License
# //creativecommons.org/licenses/by-sa/3.0/
# //foundation.wikimedia.org/wiki/Terms_of_Use
# //foundation.wikimedia.org/wiki/Privacy_policy
# //www.wikimediafoundation.org/
# https://foundation.wikimedia.org/wiki/Privacy_policy
# /wiki/Wikipedia:About
# /wiki/Wikipedia:General_disclaimer
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute
# https://foundation.wikimedia.org/wiki/Cookie_statement
# //en.m.wikipedia.org/w/index.php?title=Kevin_Bacon&mobileaction=toggle_view_mobile
# https://wikimediafoundation.org/
# https://www.mediawiki.org/

# %% [markdown]
# 항목 페이지를 가리키는 링크에는 다른 내부 페이지를 가리키는 링크와 비교되는 세 가지 공통점을 찾을 수 있다.
# 1. 이 링크들은 id가 bodyContent인 div 안에 있다.
# 1. URL에는 세미콜론이 포함되어 있지 않다.
# 1. URL은 /wiki/로 시작한다.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re # 정규 표현식을 import


html = urlopen("http://en.wikipedia.org/wiki/Kevin_Bacon")
bs0bj = BeautifulSoup(html, "html.parser")
for link in bs0bj.find("div", {"id":"bodyContent"}).findAll("a",
                                                               href=re.compile("^(/wiki/)((?!:).)*$")):
    
    if 'href' in link.attrs:
        print(link.attrs['href'])
        # href : 링크 소스

# 이 코드를 실행하면 케빈 베이컨의 위키백과 항목에서 다른 항목을 가리키는 모든 링크 목록을 볼 수 있다.
# 즉, 특정 위키백과 항목에서 다른 항목을 가리키는 모든 링크 목록을 가져온다.
# Out:
# /wiki/Kevin_Bacon_(disambiguation)
# /wiki/Philadelphia
# /wiki/Pennsylvania
# /wiki/Kyra_Sedgwick
# /wiki/Sosie_Bacon
# /wiki/Edmund_Bacon_(architect)
# /wiki/Michael_Bacon_(musician)
# /wiki/Holly_Near
# /wiki/Footloose_(1984_film)
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Sleepers
# /wiki/The_Woodsman_(2004_film)
# /wiki/Fox_Broadcasting_Company
# /wiki/The_Following
# /wiki/HBO
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award
# /wiki/Screen_Actors_Guild_Award
# /wiki/Primetime_Emmy_Award
# /wiki/The_Guardian
# /wiki/Academy_Award
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Social_networks
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/SixDegrees.org
# /wiki/Philadelphia
# /wiki/Edmund_Bacon_(architect)
# /wiki/Julia_R._Masterman_High_School
# /wiki/Pennsylvania_Governor%27s_School_for_the_Arts
# /wiki/Bucknell_University
# /wiki/Glory_Van_Scott
# /wiki/Circle_in_the_Square
# /wiki/Nancy_Mills
# /wiki/Cosmopolitan_(magazine)
# /wiki/Fraternities_and_sororities
# /wiki/Animal_House
# /wiki/Search_for_Tomorrow
# /wiki/Guiding_Light
# /wiki/Friday_the_13th_(1980_film)
# /wiki/Phoenix_Theater
# /wiki/Flux
# /wiki/Second_Stage_Theatre
# /wiki/Obie_Award
# /wiki/Forty_Deuce
# /wiki/Slab_Boys
# /wiki/Sean_Penn
# /wiki/Val_Kilmer
# /wiki/Barry_Levinson
# /wiki/Diner_(film)
# /wiki/Steve_Guttenberg
# /wiki/Daniel_Stern_(actor)
# /wiki/Mickey_Rourke
# /wiki/Tim_Daly
# /wiki/Ellen_Barkin
# /wiki/Footloose_(1984_film)
# /wiki/James_Dean
# /wiki/Rebel_Without_a_Cause
# /wiki/Mickey_Rooney
# /wiki/Judy_Garland
# /wiki/People_(American_magazine)
# /wiki/Typecasting_(acting)
# /wiki/John_Hughes_(filmmaker)
# /wiki/She%27s_Having_a_Baby
# /wiki/The_Big_Picture_(1989_film)
# /wiki/Tremors_(film)
# /wiki/Joel_Schumacher
# /wiki/Flatliners
# /wiki/Elizabeth_Perkins
# /wiki/He_Said,_She_Said_(film)
# /wiki/The_New_York_Times
# /wiki/Oliver_Stone
# /wiki/JFK_(film)
# /wiki/A_Few_Good_Men_(film)
# /wiki/Michael_Greif
# /wiki/Golden_Globe_Award
# /wiki/The_River_Wild
# /wiki/Meryl_Streep
# /wiki/Murder_in_the_First_(film)
# /wiki/Blockbuster_(entertainment)
# /wiki/Apollo_13_(film)
# /wiki/Sleepers_(film)
# /wiki/Picture_Perfect_(1997_film)
# /wiki/Losing_Chase
# /wiki/Digging_to_China
# /wiki/Payola
# /wiki/Telling_Lies_in_America_(film)
# /wiki/Wild_Things_(film)
# /wiki/Stir_of_Echoes
# /wiki/David_Koepp
# /wiki/Taking_Chance
# /wiki/Paul_Verhoeven
# /wiki/Hollow_Man
# /wiki/Colin_Firth
# /wiki/Rachel_Blanchard
# /wiki/M%C3%A9nage_%C3%A0_trois
# /wiki/Where_the_Truth_Lies
# /wiki/Atom_Egoyan
# /wiki/MPAA
# /wiki/MPAA_film_rating_system
# /wiki/Sean_Penn
# /wiki/Tim_Robbins
# /wiki/Clint_Eastwood
# /wiki/Mystic_River_(film)
# /wiki/Pedophile
# /wiki/The_Woodsman_(2004_film)
# /wiki/HBO_Films
# /wiki/Taking_Chance
# /wiki/Michael_Strobl
# /wiki/Desert_Storm
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Matthew_Vaughn
# /wiki/Sebastian_Shaw_(comics)
# /wiki/Dustin_Lance_Black
# /wiki/8_(play)
# /wiki/Perry_v._Brown
# /wiki/Proposition_8
# /wiki/Charles_J._Cooper
# /wiki/Wilshire_Ebell_Theatre
# /wiki/American_Foundation_for_Equal_Rights
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Huffington_Post
# /wiki/Tremors_(film)
# /wiki/EE_(telecommunications_company)
# /wiki/United_Kingdom
# /wiki/Egg_as_food
# /wiki/Kyra_Sedgwick
# /wiki/PBS
# /wiki/Lanford_Wilson
# /wiki/Lemon_Sky
# /wiki/Pyrates
# /wiki/Murder_in_the_First_(film)
# /wiki/The_Woodsman_(2004_film)
# /wiki/Loverboy_(2005_film)
# /wiki/Sosie_Bacon
# /wiki/Upper_West_Side
# /wiki/Manhattan
# /wiki/Tracy_Pollan
# /wiki/The_Times
# /wiki/Will.i.am
# /wiki/It%27s_a_New_Day_(Will.i.am_song)
# /wiki/Barack_Obama
# /wiki/Ponzi_scheme
# /wiki/Bernie_Madoff
# /wiki/Finding_Your_Roots
# /wiki/Henry_Louis_Gates
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Trivia
# /wiki/Big_screen
# /wiki/Six_degrees_of_separation
# /wiki/Internet_meme
# /wiki/SixDegrees.org
# /wiki/Bacon_number
# /wiki/Internet_Movie_Database
# /wiki/Paul_Erd%C5%91s
# /wiki/Erd%C5%91s_number
# /wiki/Paul_Erd%C5%91s
# /wiki/Bacon_number
# /wiki/Erd%C5%91s_number
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/The_Bacon_Brothers
# /wiki/Michael_Bacon_(musician)
# /wiki/Music_album
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Hollywood_Walk_of_Fame
# /wiki/Denver_Film_Festival
# /wiki/Phoenix_Film_Festival
# /wiki/Santa_Barbara_International_Film_Festival
# /wiki/Broadcast_Film_Critics_Association
# /wiki/Seattle_International_Film_Festival
# /wiki/Apollo_13_(film)
# /wiki/Mystic_River_(film)
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Blockbuster_Entertainment_Awards
# /wiki/Hollow_Man
# /wiki/Boston_Society_of_Film_Critics
# /wiki/Boston_Society_of_Film_Critics_Award_for_Best_Cast
# /wiki/Mystic_River_(film)
# /wiki/Bravo_Otto
# /wiki/Bravo_Otto
# /wiki/Footloose_(1984_film)
# /wiki/CableACE_Award
# /wiki/CableACE_Award
# /wiki/Losing_Chase
# /wiki/The_Woodsman_(2004_film)
# /wiki/Critics%27_Choice_Movie_Awards
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Murder_in_the_First_(film)
# /wiki/Ghent_International_Film_Festival
# /wiki/Ghent_International_Film_Festival
# /wiki/The_Woodsman_(2004_film)
# /wiki/Giffoni_Film_Festival
# /wiki/Giffoni_Film_Festival
# /wiki/Digging_to_China
# /wiki/Gold_Derby_Awards
# /wiki/Gold_Derby_Awards
# /wiki/Mystic_River_(film)
# /wiki/Golden_Globe_Award
# /wiki/Golden_Globe_Award_for_Best_Supporting_Actor_%E2%80%93_Motion_Picture
# /wiki/The_River_Wild
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Television_Series_Musical_or_Comedy
# /wiki/I_Love_Dick_(TV_series)
# /wiki/Independent_Spirit_Awards
# /wiki/Independent_Spirit_Award_for_Best_Male_Lead
# /wiki/The_Woodsman_(2004_film)
# /wiki/Mystic_River_(film)
# /wiki/MTV_Movie_%26_TV_Awards
# /wiki/MTV_Movie_Award_for_Best_Villain
# /wiki/Hollow_Man
# /wiki/Taking_Chance
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/E!_People%27s_Choice_Awards
# /wiki/The_Following
# /wiki/Primetime_Emmy_Award
# /wiki/Primetime_Emmy_Award_for_Outstanding_Lead_Actor_in_a_Limited_Series_or_Movie
# /wiki/Taking_Chance
# /wiki/Satellite_Awards
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Motion_Picture
# /wiki/The_Woodsman_(2004_film)
# /wiki/Satellite_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Taking_Chance
# /wiki/Saturn_Award
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/The_Following
# /wiki/Scream_Awards
# /wiki/Scream_Awards
# /wiki/Screen_Actors_Guild_Award
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Supporting_Role
# /wiki/Murder_in_the_First_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Apollo_13_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Mystic_River_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Cast_in_a_Motion_Picture
# /wiki/Frost/Nixon_(film)
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Taking_Chance
# /wiki/Teen_Choice_Awards
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/Beauty_Shop
# /wiki/Teen_Choice_Award_for_Choice_Movie_Villain
# /wiki/TV_Guide_Award
# /wiki/TV_Guide_Award
# /wiki/The_Following
# /wiki/Kevin_Bacon_filmography
# /wiki/List_of_actors_with_Hollywood_Walk_of_Fame_motion_picture_stars
# /wiki/The_Austin_Chronicle
# /wiki/Access_Hollywood
# /wiki/IMDb
# /wiki/Internet_Broadway_Database
# /wiki/Lortel_Archives
# /wiki/AllMovie
# /wiki/Kevin_Bacon_filmography
# /wiki/Losing_Chase
# /wiki/Loverboy_(2005_film)
# /wiki/Six_Degrees_of_Kevin_Bacon
# /wiki/Erd%C5%91s%E2%80%93Bacon_number
# /wiki/SixDegrees.org
# /wiki/Critics%27_Choice_Movie_Award_for_Best_Actor
# /wiki/Geoffrey_Rush
# /wiki/Jack_Nicholson
# /wiki/Ian_McKellen
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Russell_Crowe
# /wiki/Daniel_Day-Lewis
# /wiki/Jack_Nicholson
# /wiki/Sean_Penn
# /wiki/Jamie_Foxx
# /wiki/Philip_Seymour_Hoffman
# /wiki/Forest_Whitaker
# /wiki/Daniel_Day-Lewis
# /wiki/Sean_Penn
# /wiki/Jeff_Bridges
# /wiki/Colin_Firth
# /wiki/George_Clooney
# /wiki/Daniel_Day-Lewis
# /wiki/Matthew_McConaughey
# /wiki/Michael_Keaton
# /wiki/Leonardo_DiCaprio
# /wiki/Casey_Affleck
# /wiki/Gary_Oldman
# /wiki/Christian_Bale
# /wiki/Golden_Globe_Award_for_Best_Actor_%E2%80%93_Miniseries_or_Television_Film
# /wiki/Mickey_Rooney
# /wiki/Anthony_Andrews
# /wiki/Richard_Chamberlain
# /wiki/Ted_Danson
# /wiki/Dustin_Hoffman
# /wiki/James_Woods
# /wiki/Randy_Quaid
# /wiki/Michael_Caine
# /wiki/Stacy_Keach
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Beau_Bridges
# /wiki/Robert_Duvall
# /wiki/James_Garner
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Ving_Rhames
# /wiki/Stanley_Tucci
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/James_Franco
# /wiki/Albert_Finney
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Jonathan_Rhys_Meyers
# /wiki/Bill_Nighy
# /wiki/Jim_Broadbent
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Idris_Elba
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Billy_Bob_Thornton
# /wiki/Oscar_Isaac
# /wiki/Tom_Hiddleston
# /wiki/Ewan_McGregor
# /wiki/Darren_Criss
# /wiki/Saturn_Award_for_Best_Actor_on_Television
# /wiki/Kyle_Chandler
# /wiki/Steven_Weber_(actor)
# /wiki/Richard_Dean_Anderson
# /wiki/David_Boreanaz
# /wiki/Robert_Patrick
# /wiki/Ben_Browder
# /wiki/David_Boreanaz
# /wiki/David_Boreanaz
# /wiki/Ben_Browder
# /wiki/Matthew_Fox
# /wiki/Michael_C._Hall
# /wiki/Matthew_Fox
# /wiki/Edward_James_Olmos
# /wiki/Josh_Holloway
# /wiki/Stephen_Moyer
# /wiki/Bryan_Cranston
# /wiki/Bryan_Cranston
# /wiki/Mads_Mikkelsen
# /wiki/Hugh_Dancy
# /wiki/Andrew_Lincoln
# /wiki/Bruce_Campbell
# /wiki/Andrew_Lincoln
# /wiki/Kyle_MacLachlan
# /wiki/Sam_Heughan
# /wiki/Screen_Actors_Guild_Award_for_Outstanding_Performance_by_a_Male_Actor_in_a_Miniseries_or_Television_Movie
# /wiki/Raul_Julia
# /wiki/Gary_Sinise
# /wiki/Alan_Rickman
# /wiki/Gary_Sinise
# /wiki/Christopher_Reeve
# /wiki/Jack_Lemmon
# /wiki/Brian_Dennehy
# /wiki/Ben_Kingsley
# /wiki/William_H._Macy
# /wiki/Al_Pacino
# /wiki/Geoffrey_Rush
# /wiki/Paul_Newman
# /wiki/Jeremy_Irons
# /wiki/Kevin_Kline
# /wiki/Paul_Giamatti
# /wiki/Al_Pacino
# /wiki/Paul_Giamatti
# /wiki/Kevin_Costner
# /wiki/Michael_Douglas
# /wiki/Mark_Ruffalo
# /wiki/Idris_Elba
# /wiki/Bryan_Cranston
# /wiki/Alexander_Skarsg%C3%A5rd
# /wiki/Darren_Criss
# /wiki/Bibsys
# /wiki/Biblioteca_Nacional_de_Espa%C3%B1a
# /wiki/Biblioth%C3%A8que_nationale_de_France
# /wiki/Integrated_Authority_File
# /wiki/International_Standard_Name_Identifier
# /wiki/Library_of_Congress_Control_Number
# /wiki/National_Library_of_Latvia
# /wiki/MusicBrainz
# /wiki/National_Library_of_the_Czech_Republic
# /wiki/National_Library_of_Australia
# /wiki/National_Library_of_Australia
# /wiki/National_Library_of_Israel
# /wiki/National_Library_of_Poland
# /wiki/Royal_Library_of_the_Netherlands
# /wiki/RERO_(Library_Network_of_Western_Switzerland)
# /wiki/SNAC
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# /wiki/Virtual_International_Authority_File
# /wiki/WorldCat_Identities

# %% [markdown]
# 위의 스크립트가 흥미롭기는 하지만 현실적으로는 별 쓸모가 없다. 이 코드는 다음과 같은 형태로 바꿀 수 있어야 한다.
# 1. /wiki/<article_name> 형태인 위키백과 항목 URL을 받고, 링크된 항목 URL 목록 전체를 반환하는 getLinks 함수
# 1. 시작 항목에서 getLinks를 호출하고 반환된 리스트에서 무작위로 항목 링크를 선택하여 getLinks를 다시 호출하는 작업을,
#    프로그램을 끝내거나 새 페이지에 항목 링크가 없을 때까지 반복하는 메인 함수

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re # 정규 표현식을 import
import datetime
import random
random.seed(datetime.datetime.now())
# 현재 시스템 시간을 가지고 난수 발생기를 실행하는 것. 
# 이렇게 하면 프로그램을 실행할 때마다 위키백과 항목들 속에서 새롭고 흥미로운 무작위 경로를  찾을 수 있다.

def getLinks(articleUrl):
    html = urlopen("http://en.wikipedia.org"+articleUrl)
    bs0bj = BeautifulSoup(html, "html.parser")
    return bs0bj.find("div", {"id":"bodyContent"}).findAll("a",
                                                               href=re.compile("^(/wiki/)((?!:).)*$"))
"""
이 함수는 /wiki/.. 형태로 된 URL을 받고, 그 앞에 위키백과 도메인 이름을 붙여,
그 위치의 HTML에서 BeautifulSoup 객체를 가져온다.
매개변수에 따라 항목 링크 태그 목록을 추출해서 반환한다.
"""

links = getLinks("/wiki/Kevin_Bacon") # 초기 페이지 설정

while len(links) > 0:
    newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
    # 항목을 무작위로 선택하고 선택한 링크에서 href 속성을 추출하고,
    # 페이지를 출력하고, 추출한 URL에서 새 링크 목록을 가져오는 작업을 반복한다.
    print(newArticle)
    links = getLinks(newArticle)
# Out:
# /wiki/Daniel_Day-Lewis
# /wiki/Jon_Voight
# /wiki/Academy_Award_for_Best_Actor
# /wiki/Academy_Award_for_Best_Cinematography
# /wiki/List_of_Pakistani_Academy_Award_winners_and_nominees
# /wiki/John_A._Bonner_Medal_of_Commendation
# /wiki/Academy_Award_for_Technical_Achievement
# /wiki/48th_Academy_Awards
# /wiki/Robert_Surtees_(cinematographer)
# /wiki/Winton_C._Hoch
# /wiki/Nanny_and_the_Professor
# /wiki/Richard_Long_(actor)
# /wiki/Lawman_(TV_series)
# /wiki/DeForest_Kelley
# /wiki/Tom_McLaury
# /wiki/John_Joel_Glanton
# /wiki/Magdalena,_New_Mexico
# /wiki/United_States_Census_Bureau
# /wiki/Social_Security_Administration
# /wiki/Ida_May_Fuller
# /wiki/Brattleboro,_Vermont
# /wiki/1820_United_States_Census
# /wiki/Virginia
# /wiki/Featherstone_National_Wildlife_Refuge
# /wiki/George_Washington_Birthplace_National_Monument
# /wiki/George_Washington
# /wiki/Merrill_Jensen
# /wiki/University_of_Washington
# /wiki/American_football
# /wiki/Camping_(game)
# /wiki/East_Anglia
# /wiki/Kingdom_of_East_Anglia
# /wiki/List_of_monarchs_of_East_Anglia
# /wiki/Ecclesiastical_History_of_the_English_People
# /wiki/Strasbourg,_France
# /wiki/Vauban
# /wiki/Menno_van_Coehoorn
# /wiki/Luxembourg
# /wiki/Portuguese_Luxembourger
# /wiki/ArcelorMittal
# /wiki/Senegal
# /wiki/Syria
# /wiki/Demographics_of_the_Middle_East
# /wiki/Demographics_of_the_United_Arab_Emirates
# /wiki/Demographics_of_Cambodia
# /wiki/Tai_peoples
# /wiki/Sikkimese_people
# /wiki/Lachung_River
# /wiki/Kangchenjunga
# /wiki/Eight-thousander
# /wiki/Gerlinde_Kaltenbrunner
# /wiki/Integrated_Authority_File
# /wiki/Biografisch_Portaal
# /wiki/IP_address
# /wiki/Microsoft
# /wiki/Wayback_Machine
# /wiki/EchoStar
# /wiki/SSL_1300
# /wiki/Telesat
# /wiki/Ontario
# /wiki/Territorial_evolution_of_Canada
# /wiki/List_of_Canadian_provinces_and_territories_by_Human_Development_Index
# /wiki/List_of_districts_of_Sierra_Leone_by_Human_Development_Index
# /wiki/Bombali_District
# /wiki/Holy_Spirit_Hospital_(Makeni)
# /wiki/Nursing
# /wiki/Community_college
# /wiki/Charter_school
# /wiki/Comprehensive_school
# /wiki/Higher_education
# /wiki/Adult_education
# /wiki/Education_in_Guyana
# /wiki/Education_in_Chile
# /wiki/Sport_in_Chile
# /wiki/Copa_Libertadores
# /wiki/Copa_Am%C3%A9rica_Femenina_de_Futsal
# /wiki/Copa_Am%C3%A9rica_Femenina
# /wiki/Intercontinental_Cup_(football)
# /wiki/1971_Intercontinental_Cup
# /wiki/Uruguay
# /wiki/B%C3%BAsqueda
# /wiki/Ali_Abu_al-Ragheb
# /wiki/Rashid_Tali%27a
# /wiki/Samir_al-Rifai
# /wiki/Rashid_Tali%27a
# /wiki/Rida_Pasha_al-Rikabi
# /wiki/Faisal_al-Fayez
# /wiki/Zaid_al-Rifai
# /wiki/Ahmad_al-Lawzi
# /wiki/Kassim_al-Rimawi
# /wiki/Mandatory_Palestine
# /wiki/Circassians
# /wiki/%C4%B0stanbul
# /wiki/Eurovision_Song_Contest_2004
# /wiki/United_Kingdom_in_the_Eurovision_Song_Contest
# /wiki/Rikki_(British_singer)
# /wiki/Emma_(Welsh_singer)
# /wiki/Never_Give_Up_on_You
# /wiki/Bryan_Johnson_(singer)
# /wiki/Siw_Malmkvist
# /wiki/Nick_Cave
# /wiki/United_Kingdom
# /wiki/Germans_in_the_United_Kingdom
# /wiki/Lithuanians_in_the_United_Kingdom
# /wiki/Italians_in_the_United_Kingdom
# /wiki/Ukrainians_in_the_United_Kingdom
# /wiki/Hutsuls
# /wiki/University_of_Toronto_Press
# /wiki/University_of_Toronto_Libraries
# /wiki/Syst%C3%A8me_universitaire_de_documentation
# /wiki/Historical_Dictionary_of_Switzerland#Lexicon_Istoric_Retic
# /wiki/Union_List_of_Artist_Names
# /wiki/Information_Center_for_Israeli_Art
# /wiki/Geographic_coordinate_system
# /wiki/Quasi-Zenith_Satellite_System
# /wiki/BS-3H
# /wiki/Satellite_bus
# /wiki/I-4K
# /wiki/Indian_Mini_Satellite_bus
# /wiki/I-2K
# /wiki/I-3K
# /wiki/I-2K
# /wiki/GSAT-7
# /wiki/Resurs-P_No.1
# /wiki/2014_in_spaceflight
# /wiki/Mars_Orbiter_Mission
# /wiki/Inmarsat-5_F1
# /wiki/London_and_Provincial_District_Telegraph_Company
# /wiki/Defence_Science_and_Technology_Laboratory
# /wiki/Vickers_Limited
# /wiki/Miles_Aircraft
# /wiki/Short_Brothers
# /wiki/Short_Bomber
# /wiki/Short_Type_301
# /wiki/Short_S.38
# /wiki/United_Kingdom_military_aircraft_serials
# /wiki/Fairey_IIIF
# /wiki/Fleet_Air_Arm
# /wiki/National_Maritime_Museum
# /wiki/Old_Operating_Theatre_Museum_and_Herb_Garret
# /wiki/Royal_Mews
# /wiki/Bentley_State_Limousine
# /wiki/%C5%A0koda_Auto
# /wiki/Czechoslovakia
# /wiki/Malta
# /wiki/Gwardaman%C4%A1a
# /wiki/Paceville
# /wiki/Sheraton_Hotels_and_Resorts
# /wiki/United_Hotels_Company_of_America
# /wiki/Hospitality_International
# /wiki/Best_Western
# /wiki/Hyatt
# /wiki/Ticker_symbol
# /wiki/Astra_AB
# /wiki/Ticagrelor
# /wiki/Prescription_drug
# /wiki/Mood_stabilizer
# /wiki/Topoisomerase_inhibitor
# /wiki/Masoprocol
# /wiki/Arsenic_trioxide
# /wiki/Niobium
# /wiki/Magnetism
# /wiki/History_of_science_and_technology_in_China
# /wiki/SN_1006
# /wiki/Lupus_(constellation)
# /wiki/Pegasus_(constellation)
# /wiki/V391_Pegasi
# /wiki/Variable_star
# /wiki/Trifid_Nebula
# /wiki/Minute_of_arc
# /wiki/Decimal
# /wiki/Base-6
# /wiki/Thai_numerals
# /wiki/Complex-base_system
# /wiki/Decimal
# /wiki/Nat_(unit)
# /wiki/Joule
# /wiki/British_thermal_unit
# /wiki/United_States_customary_units
# /wiki/Millilitre
# /wiki/Joule
# /wiki/Mole_(unit)
# /wiki/Bibcode
# /wiki/International_Standard_Book_Number
# /wiki/International_Standard_Text_Code
# /wiki/ISO_11940
# /wiki/ISO_10383
# /wiki/International_Standard_Recording_Code
# /wiki/ISO_8501-1
# /wiki/MPEG-4_Part_14
# /wiki/British_Standard_Pipe
# /wiki/ISO_999
# /wiki/ISO_15897
# /wiki/International_Standard_Musical_Work_Code
# /wiki/EXPRESS_(data_modeling_language)
# /wiki/ISO_2852
# /wiki/ISO_4
# /wiki/ISO_10160
# /wiki/International_Standard_Audiovisual_Number
# /wiki/Power_take-off
# /wiki/Water_Resistant_mark
# /wiki/Meta-Object_Facility
# /wiki/ISO_11898
# /wiki/FASTBUS
# /wiki/AES3
# /wiki/International_Electrotechnical_Commission
# /wiki/American_National_Standards_Institute
# /wiki/International_Standard_Name_Identifier
# /wiki/ISO_4031
# /wiki/ISO_8178
# /wiki/ECMAScript
# /wiki/ISO/IEC_17024
# /wiki/ISO_14971
# /wiki/MPEG-4_Part_12
# /wiki/RatDVD
# /wiki/MPEG-1
# /wiki/PHIGS
# /wiki/List_of_ISO_romanizations
# /wiki/Chinese_language_romanisation_in_Singapore
# /wiki/Hong_Kong
# /wiki/Cancer
# /wiki/Specialty_(medicine)
# /wiki/Palliative_care
# /wiki/Cicely_Saunders
# /wiki/FRCS
# /wiki/Robert_Keate
# /wiki/John_Keate
# /wiki/Edmond_Warre
# /wiki/James_John_Hornby
# /wiki/List_of_Oxford_University_Boat_Race_crews
# /wiki/The_Boat_Race_1859
# /wiki/The_Boat_Race_1994
# /wiki/The_Boat_Race_1952
# /wiki/The_Manchester_Guardian
# /wiki/Le_Monde
# /wiki/List_of_French_newspapers
# /wiki/Sarthe
# /wiki/Vend%C3%A9e
# /wiki/Les_Chouans
# /wiki/The_Picture_of_Dorian_Gray_(1976_TV)
# /wiki/Dorian_Gray_(2009_film)
# /wiki/Ealing_Studios
# /wiki/List_of_British_films_of_1988
# /wiki/Chris_Lemmon
# /wiki/Academy_Awards
# /wiki/William_Friedkin
# /wiki/Joseph_L._Mankiewicz
# /wiki/Anti-Communism
# /wiki/Communist_Romania
# /wiki/Politburo
# /wiki/Politburo_of_the_Workers%27_Party_of_Korea
# /wiki/JSTOR
# /wiki/Data_theft
# /wiki/IPod
# /wiki/Larry_Ellison
# /wiki/MiG-29
# /wiki/TVN_24
# /wiki/Belsat_TV
# /wiki/Soviet_Union
# /wiki/Cinema_of_Russia
# /wiki/Cinema_of_Saudi_Arabia
# /wiki/Keif_al-Hal%3F
# /wiki/Saudi_Arabia
# /wiki/Economy_of_Nigeria
# /wiki/Economy_of_Liechtenstein
# /wiki/Municipalities_of_Liechtenstein
# /wiki/Elections_in_Liechtenstein
# /wiki/1962_Liechtenstein_general_election
# /wiki/1987_Liechtenstein_double_yes_referendum
# /wiki/1929_Liechtenstein_alcohol_tax_referendum
# /wiki/1937_Liechtenstein_department_stores_referendum
# /wiki/1922_Liechtenstein_tax_law_referendum
# /wiki/1985_Liechtenstein_referendums
# /wiki/1962_Liechtenstein_general_election
# /wiki/Patriotic_Union_(Liechtenstein)
# /wiki/February_1993_Liechtenstein_general_election
# /wiki/2005_Liechtenstein_constitutional_referendum
# /wiki/2012_Liechtenstein_constitutional_referendum
# /wiki/April_1926_Liechtenstein_general_election
# /wiki/1922_Liechtenstein_tax_law_referendum
# /wiki/1935_Liechtenstein_electoral_system_referendum
# /wiki/1931_Liechtenstein_unemployment_insurance_referendum
# /wiki/1992_Liechtenstein_referendums
# /wiki/1932_Liechtenstein_electoral_system_referendum
# /wiki/Municipalities_of_Liechtenstein
# /wiki/List_of_Presidents_of_the_Landtag_of_Liechtenstein
# /wiki/Ernst_Walch
# /wiki/Parliament_of_Liechtenstein
# /wiki/National_Council_(Monaco)
# /wiki/Parliament_of_Azerbaijan
# /wiki/Parliament_of_Turkey
# /wiki/Mustafa_%C5%9Eentop
# /wiki/Mithat_Sancar
# /wiki/November_2015_Turkish_general_election
# /wiki/G%C3%BCm%C3%BC%C5%9Fhane_(electoral_district)#November_2015
# /wiki/Turkish_general_election,_1923
# /wiki/Governor_(Turkey)
# /wiki/Governor_of_Mu%C4%9Fla
# /wiki/Governor_of_%C4%B0stanbul
# /wiki/Arnavutk%C3%B6y_(district)
# /wiki/Sancaktepe
# /wiki/%C3%87orum_Province
# /wiki/El%C3%A2z%C4%B1%C4%9F_Province
# /wiki/Turkish_people
# /wiki/International_Standard_Book_Number
# /wiki/ISO_2145
# /wiki/Salt_spray_test
# /wiki/Language_Of_Temporal_Ordering_Specification
# /wiki/International_Standard_Serial_Number
# /wiki/Digital_object_identifier
# /wiki/ISO_6344
# /wiki/ISO_3166
# /wiki/Geographic_coding
# /wiki/Nomenclature_of_Territorial_Units_for_Statistics
# /wiki/Region_(Europe)
# /wiki/Latvia
# /wiki/Al%C5%ABksne
# /wiki/Joni%C5%A1kis
# /wiki/Time_zone
# /wiki/Comoros
# /wiki/Arabic_language
# /wiki/Bahrani_Arabic
# /wiki/Arabic_Sign_Language
# /wiki/Egyptian_Sign_Language
# /wiki/Latvian_Sign_Language
# /wiki/Algerian_Sign_Language
# /wiki/Saudi_Sign_Language
# /wiki/Orientation_(sign_language)
# /wiki/Mayan_Sign_Language
# /wiki/Chatino_Sign_Language
# /wiki/Varieties_of_American_Sign_Language
# /wiki/BANZSL
# /wiki/Kuwaiti_Sign_Language
# /wiki/Valencian_Sign_Language
# /wiki/Trinidad_and_Tobago_Sign_Language
# /wiki/International_Standard_Serial_Number
# /wiki/Web_Content_Accessibility_Guidelines
# /wiki/Tim_Berners-Lee
# /wiki/Hypertext_Transfer_Protocol
# /wiki/HReview
# /wiki/TriX_(serialization_format)
# /wiki/Rule-based_system
# /wiki/Common_Logic
# /wiki/International_Electrotechnical_Commission
# /wiki/Indonesia
# /wiki/Buddhism
# /wiki/Conservative_Judaism
# /wiki/Joel_Roth
# /wiki/Daniel_Nevins
# /wiki/Wexner_Foundation
# /wiki/Wayback_Machine
# /wiki/Collective_memory
# /wiki/Imagination_inflation
# /wiki/Selective_amnesia
# /wiki/Procedural_memory
# /wiki/Deese%E2%80%93Roediger%E2%80%93McDermott_paradigm
# /wiki/Visual_memory
# /wiki/False_memory
# /wiki/Digital_object_identifier
# /wiki/International_Securities_Identification_Number
# /wiki/ISO/TR_11941
# /wiki/ISO_6346
# /wiki/Language_Of_Temporal_Ordering_Specification
# /wiki/MPEG-4_Part_14
# /wiki/ISO/IEC_8859-13
# /wiki/CDC_display_code
# /wiki/6_(number)
# /wiki/775_(number)
# /wiki/848_(number)
# /wiki/424_(number)
# /wiki/282_(number)
# /wiki/281_(number)
# /wiki/158_(number)
# /wiki/483_(number)
# /wiki/146_(number)
# /wiki/United_States_Navy
# /wiki/International_rankings_of_the_United_States
# /wiki/Homelessness_in_the_United_States
# /wiki/Pet_ownership_among_the_homeless
# /wiki/Digital_object_identifier
# /wiki/Persistent_identifier
# /wiki/Uniform_Resource_Name
# /wiki/IETF
# /wiki/RFC_Editor
# /wiki/Jeff_Rulifson
# /wiki/International_Standard_Book_Number
# /wiki/ETTN
# /wiki/Electronic-books
# /wiki/Association_of_American_University_Presses
# /wiki/American_Historical_Association
# /wiki/Smithsonian_Institution
# /wiki/Andrew_Jackson
# /wiki/William_Rush
# /wiki/Philadelphia_Museum_of_Art
# /wiki/Spring_Garden,_Philadelphia
# /wiki/Elmwood_Park,_Philadelphia
# /wiki/East_Falls,_Philadelphia
# /wiki/Upper_Holmesburg,_Philadelphia
# /wiki/Stanton,_Philadelphia
# /wiki/Cedarbrook,_Philadelphia
# /wiki/Paschall,_Philadelphia
# /wiki/Jewelers%27_Row,_Philadelphia
# /wiki/Liberty_Bell
# /wiki/Olin_Partnership
# /wiki/Jack_Whitten
# /wiki/Barbara_Jordan
# /wiki/Myra_Bradwell
# /wiki/Hannah_G._Solomon
# /wiki/Victoria_Woodhull
# /wiki/Naomi_Wolf
# /wiki/Royal_Library_of_the_Netherlands
# /wiki/Corruption_in_the_Netherlands
# /wiki/Corruption_in_Moldova
# /wiki/Corruption_in_Finland
# /wiki/Corruption
# /wiki/Anti-Corruption_Foundation
# /wiki/Leviathan_(2014_film)
# /wiki/Kolya
# /wiki/Ond%C5%99ej_Vetch%C3%BD
# /wiki/Dark_Blue_World
# /wiki/Rotten_Tomatoes
# /wiki/The_Hollywood_Reporter
# /wiki/OK!
# /wiki/Jenny_Frost
# /wiki/Kerry_Katona
# /wiki/International_Standard_Book_Number
# /wiki/R.R._Bowker
# /wiki/American_Architects_Directory
# /wiki/American_Institute_of_Architects
# /wiki/Philadelphia
# /wiki/Black_Hispanic_and_Latino_Americans
# /wiki/Fijian_Americans
# /wiki/List_of_Uzbek_Americans
# /wiki/List_of_Guyanese_Americans
# /wiki/Central_Africans_in_the_United_States
# /wiki/Mauritanian_Americans
# /wiki/Fula_Americans
# /wiki/Moroccan_Americans
# /wiki/Berbers_in_France
# /wiki/Czech_migration_to_France
# /wiki/Silesians
# /wiki/Silesian_language
# /wiki/Czech_Silesia
# /wiki/David_Zeisberger
# /wiki/LIBRIS
# /wiki/ResearcherID
# /wiki/National_Archives_and_Records_Administration
# /wiki/International_Standard_Book_Number
# /wiki/ISO/IEC_7811
# /wiki/ISO_15926_WIP
# /wiki/ISO_19136
# /wiki/Soterml
# /wiki/Linguistics
# /wiki/Speech_community
# /wiki/Society
# /wiki/John_Rawls
# /wiki/John_Stuart_Mill
# /wiki/H%C3%A9l%C3%A8ne_Cixous
# /wiki/International_Standard_Book_Number
# /wiki/ISO_31-1
# /wiki/ISO_5964
# /wiki/ISO_25964-1
# /wiki/ISO_10218
# /wiki/ISO_259
# /wiki/Patah
# /wiki/Tag_(Hebrew_writing)
# /wiki/Nun_(letter)
# /wiki/Segolate
# /wiki/Cursive_Hebrew
# /wiki/Mandaic_script
# /wiki/Tactile_alphabet
# /wiki/Devanagari_Braille
# /wiki/Chhattisgarhi_language
# /wiki/Palula_language
# /wiki/Gujarati_language
# /wiki/Gawar-Bati_language
# /wiki/Wazir_dialect
# /wiki/Kaniguram
# /wiki/Waziristani_dialect
# /wiki/Jadgali_language
# /wiki/Goaria_language
# /wiki/Punjabi_dialects
# /wiki/Bagheli_language
# /wiki/Pahari-Pothwari
# /wiki/Hyderabadi_Urdu
# /wiki/Northern_Indo-Aryan_languages
# /wiki/Kochila_Tharu
# /wiki/Maldivian_language
# /wiki/Xavier_Romero-Frias
# /wiki/Maldivians
# /wiki/Ernakulam
# /wiki/Nadapuram
# /wiki/Kondotty
# /wiki/Thalassery
# /wiki/Kottarakkara
# /wiki/Sakthikulangara
# /wiki/R.S._Unni
# /wiki/A._A._Aziz
# /wiki/P._Ravindran
# /wiki/Baby_John
# /wiki/R._S._Unni
# /wiki/A._A._Rahim
# /wiki/Travancore-Cochin
# /wiki/Pandalam
# /wiki/Thumpamon_Vadakkumnatha_Temple
# /wiki/Viswanatha_Swamy_Temple,_Palakkad
# /wiki/Choorakkottukavu_Bhagavathy_Temple
# /wiki/Kodungallur_Bhagavathy_Temple
# /wiki/Sarada_Mutt
# /wiki/Sri_Siddhi_Vinayakar_Temple,_Chittampara
# /wiki/Thrippakudam
# /wiki/Shatrughna_Temple
# /wiki/Cherukunnu#Annapoorneshwari_Temple
# /wiki/Mannar,_Alappuzha
# /wiki/Postal_Index_Number
# /wiki/Postal_codes_in_Afghanistan
# /wiki/Afghan_Post
# /wiki/Gurjar
# /wiki/Jat_people
# /wiki/Khatkar
# /wiki/Jhanjhar
# /wiki/Bhilwara
# /wiki/List_of_regions_in_India
# /wiki/Colonial_India
# /wiki/Partition_of_India
# /wiki/Western_Punjab
# /wiki/Gujranwala
# /wiki/Pakistan
# /wiki/Saint_Lucia
# /wiki/New_Brunswick
# /wiki/Ontario
# /wiki/List_of_the_100_largest_population_centres_in_Canada
# /wiki/Demographics_of_Newfoundland_and_Labrador
# /wiki/Italian_Canadians
# /wiki/Hungarian_Canadians
# /wiki/Whitewood,_Saskatchewan
# /wiki/List_of_communities_in_Saskatchewan
# /wiki/Ketchen,_Saskatchewan
# /wiki/Saskatchewan
# /wiki/Weyburn
# /wiki/2006_Canadian_Census
# /wiki/Korean_Canadians
# /wiki/Interprovincial_migration_in_Canada
# /wiki/Canadian_values
# /wiki/Conscription_Crisis_of_1917
# /wiki/Sir_Albert_Edward_Kemp
# /wiki/Minister_of_National_Defence_(Canada)
# /wiki/Minister_of_Justice_(Canada)
# /wiki/Attorney_General_of_the_Turks_and_Caicos_Islands
# /wiki/Attorney_General_of_Trinidad_and_Tobago
# /wiki/Dominion_of_New_Zealand
# /wiki/M%C4%81ori_language
# /wiki/Orthography
# /wiki/Old_English
# /wiki/Harcourt_Trade_Publishers
# /wiki/General_Cinema_Corporation
# /wiki/Loyalty_program
# /wiki/Credit_card
# /wiki/Frank_X._McNamara
# /wiki/Installment_credit
# /wiki/Tribal_Lending_Enterprise
# /wiki/Picayune_Rancheria_of_Chukchansi_Indians
# /wiki/Middletown_Rancheria_of_Pomo_Indians_of_California
# /wiki/Seigler_Springs,_California
# /wiki/Bertha,_California
# /wiki/Borax_Springs,_California
# /wiki/Glenhaven,_California
# /wiki/Lakeport,_California
# /wiki/Colusa,_California
# /wiki/Colusa_Unified_School_District
# /wiki/Middle_school
# /wiki/Pre-kindergarten
# /wiki/Education_in_Indonesia
# /wiki/Indonesian_National_Armed_Forces
# /wiki/Garuda_Contingent
# /wiki/International_Standard_Book_Number
# /wiki/Film_speed
# /wiki/ISO_3166-1
# /wiki/ISO_3166-1_alpha-2#NO
# /wiki/United_States_Minor_Outlying_Islands
# /wiki/Top-level_domain
# /wiki/.eco
# /wiki/.jobs
# /wiki/.tel
# /wiki/Internationalized_domain_name
# /wiki/German_language
# /wiki/Proper_noun
# /wiki/Onomastics
# /wiki/Greek_Cypriot_name
# /wiki/Naming_in_the_United_States
# /wiki/Home-ownership_in_the_United_States
# /wiki/List_of_mountains_of_the_United_States
# /wiki/List_of_state_legislature_Speakers
# /wiki/List_of_U.S._state_partition_proposals
# /wiki/J.H._Colton
# /wiki/Library_of_Congress
# /wiki/United_States_Copyright_Office
# /wiki/United_States_congressional_subcommittee
# /wiki/United_States_Senate_Committee_on_the_Budget
# /wiki/United_States_Democratic_Party
# /wiki/The_Gallup_Organization
# /wiki/Chief_executive_officer
# /wiki/Corporate_governance
# /wiki/International_Standard_Book_Number
# /wiki/MPEG-4_Part_14
# /wiki/ISO_12006
# /wiki/ISO_11940
# /wiki/Common_Locale_Data_Repository
# /wiki/%27Phags-pa_script
# /wiki/South_African_braille
# /wiki/Samoan_Braille
# /wiki/Yugoslav_Braille
# /wiki/Slovene_alphabet
# /wiki/Albanian_alphabet
# /wiki/U
# /wiki/Bar_(diacritic)
# /wiki/%EA%94%8F
# /wiki/International_maritime_signal_flags
# /wiki/Mountbatten_Brailler
# /wiki/Braille_kanji
# /wiki/Hida_dialect
# /wiki/Japanese_poetry
# /wiki/Hagiwara_Sakutar%C5%8D
# /wiki/Mandolin
# /wiki/Lute
# /wiki/List_of_Renaissance_composers
# /wiki/Ji%C5%99%C3%AD_Rychnovsk%C3%BD
# /wiki/Integrated_Authority_File
# /wiki/SNAC
# /wiki/Museum_of_New_Zealand_Te_Papa_Tongarewa
# /wiki/Taonga
# /wiki/M%C4%81ori_language
# /wiki/Mandarin_Chinese
# /wiki/Then_language
# /wiki/Hezhang_Buyi_language
# /wiki/Zhuang_languages
# /wiki/Cao_Miao_language
# /wiki/Mili_language
# /wiki/Daur_language
# /wiki/Kra-Dai_languages
# /wiki/Esmeralda%E2%80%93Yaruroan_languages
# /wiki/Catacaoan_languages
# /wiki/Peru
# /wiki/Pre-Columbian_Peru
# /wiki/Lima_Region
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~\Anaconda3\lib\http\client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~\Anaconda3\lib\http\client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# ~\Anaconda3\lib\http\client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-11-e7a507a812e1> in <module>
#      23     newArticle = links[random.randint(0, len(links)-1)].attrs["href"]
#      24     print(newArticle)
# ---> 25     links = getLinks(newArticle)
#      26
#
# <ipython-input-11-e7a507a812e1> in getLinks(articleUrl)
#       9
#      10 def getLinks(articleUrl):
# ---> 11     html = urlopen("http://en.wikipedia.org"+articleUrl)
#      12     bs0bj = BeautifulSoup(html, "html.parser")
#      13     return bs0bj.find("div", {"id":"bodyContent"}).findAll("a",
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#    1321         except:
#
# URLError: <urlopen error [WinError 10060] 연결된 구성원으로부터 응답이 없어 연결하지 못했거나, 호스트로부터 응답이 없어 연결이 끊어졌습니다>

# %% [markdown]
# ### 전체 사이트 크롤링
# - 장점
#     1. 사이트맵 생성
#     1. 데이터 수집

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen("http://en.wikipedia.org"+pageUrl)
    bs0bj = BeautifulSoup(html, "html.parser")
    for link in bs0bj.findAll("a", href=re.compile("^(/wiki/)")):
        # /wiki/ 로 시작하는 모든 링크를 찾는다.
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                # 새 페이지를 발견
                newPage = link.attrs['href']
                print(newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks("")
# Out:
# /wiki/Wikipedia
# /wiki/Wikipedia:Protection_policy#semi
# /wiki/Wikipedia:Requests_for_page_protection
# /wiki/Wikipedia:Requests_for_permissions
# /wiki/Wikipedia:Protection_policy#extended
# /wiki/Wikipedia:Lists_of_protected_pages
# /wiki/Wikipedia:Protection_policy
# /wiki/Wikipedia:Perennial_proposals
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# /wiki/Wikipedia:Reliable_sources
# /wiki/Wikipedia:RS_(disambiguation)
# /wiki/Wikipedia:WikiProject_Radio_Stations
# /wiki/File:People_icon.svg
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# /wiki/Help:What_links_here
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# /wiki/Wikipedia:Protection_policy#move
# /wiki/Wikipedia:WPPP
# /wiki/File:People_icon_dead.svg
# /wiki/User:StevenDH
# /wiki/Wikipedia:User_pages
# /wiki/Wikipedia:FUW
# /wiki/Wikipedia:Protection_policy#template
# /wiki/Wikipedia:Party_and_person
# /wiki/File:Essay.svg
# /wiki/File:Essay.png
# /wiki/File:To_Commons.svg
# /wiki/Special:WhatLinksHere/File:To_Commons.svg
# /wiki/User_talk:Robert_Merkel
# /wiki/User_talk:Robert_Merkel/ancient
# /wiki/User:RjLesch
# /wiki/Des_Moines,_Iowa
# /wiki/Des_Moines_(disambiguation)
# /wiki/Des_Moines_metropolitan_area
# /wiki/Geographic_coordinate_system
# /wiki/Template:Coord
# /wiki/Template:Coord/doc
# /wiki/Wikipedia:Template_documentation
# /wiki/File:Twemoji_1f527.svg
# /wiki/Special:WhatLinksHere/File:Twemoji_1f527.svg
# /wiki/Help:Editing
# /wiki/Wikipedia:Editing_policy
# /wiki/Wikipedia:List_of_guidelines#Editing
# /wiki/Wikipedia:List_of_policies
# /wiki/Template:Nutshell
# /wiki/Template:Nutshell/doc
# /wiki/Wikipedia:Subpages
# /wiki/Wikipedia:SP_(disambiguation)
# /wiki/Wikipedia:SP
# /wiki/Wikipedia:Substitution
# /wiki/Help:Substitution
# /wiki/Wikipedia:Project_namespace#Wikipedia_how-to_and_information_pages
# /wiki/Wikipedia:Policies_and_guidelines
# /wiki/Wikipedia:Portal/Guidelines
# /wiki/Wikipedia:Portal
# /wiki/Wikipedia:WikiProject_Portals
# /wiki/Portal:Contents/Portals
# /wiki/Portal:Contents
# /wiki/Portal:Contents/Overviews
# /wiki/Portal:Contents/Outlines
# /wiki/Portal:Contents/Lists
# /wiki/Portal:Contents/Glossaries
# /wiki/Portal:Contents/Categories
# /wiki/Portal:Contents/Indices
# /wiki/Portal:Contents/Reference
# /wiki/Portal:Contents/Culture_and_the_arts
# /wiki/Wikipedia:CFORK
# /wiki/Category:Wikipedia_content_guidelines
# /wiki/Help:Category
# /wiki/Wikipedia:Categorization
# /wiki/Wikipedia:WikiProject_Cats
# /wiki/Wikipedia:CATP
# /wiki/Wikipedia:WikiProject
# /wiki/Wikipedia:Wikimedia_sister_projects
# /wiki/Help:Interwikimedia_links
# /wiki/Help:Interlanguage_links
# /wiki/List_of_ISO_639-1_codes
# /wiki/File:Question_book-new.svg
# /wiki/Wikipedia:Protection_policy#full
# /wiki/Wikipedia:Child_protection
# /wiki/Wikipedia:Biographies_of_living_persons
# /wiki/Wikipedia:Biographies_of_living_persons/Noticeboard
# /wiki/Template:Noticeboard_links
# /wiki/Template_talk:Noticeboard_links
# /wiki/Wikipedia:Talk_page_guidelines
# /wiki/Help:Talk_pages
# /wiki/Help:Template
# /wiki/Wikipedia:Template_messages
# /wiki/MOS:TM
# /wiki/Wikipedia:Manual_of_Style
# /wiki/Wikipedia:Policies_and_guidelines#guide
# /wiki/Wikipedia:List_of_policies#Procedural
# /wiki/Wikipedia_talk:List_of_policies
# /wiki/File:Peacedove.svg
# /wiki/Special:WhatLinksHere/File:Peacedove.svg
# /wiki/Talk:Kashmir
# /wiki/Kashmir
# /wiki/Kashmar
# /wiki/Kashmar_County
# /wiki/Counties_of_Iran
# /wiki/File:Iran_Counties.svg
# /wiki/County
# /wiki/Country
# /wiki/Country_(disambiguation)
# /wiki/Rural_area
# /wiki/Rural_(disambiguation)
# /wiki/Rural
# /wiki/File:Barossa_Valley_South_Australia.jpg
# /wiki/Australian_wine
# /wiki/File:Australian_Wine.jpg
# /wiki/Canon_(company)
# /wiki/File:Canon_wordmark.svg
# /wiki/Canon_IT_Solutions
# /wiki/List_of_legal_entity_types_by_country
# /wiki/Company_(disambiguation)
# /wiki/Company
# /wiki/And_Co
# /wiki/File:And_Co_logo.jpg
# /wiki/Color_space
# /wiki/Wikipedia:Verifiability
# /wiki/Wikipedia:Reliable_sources/Noticeboard
# /wiki/Wikipedia:Noticeboards
# /wiki/Wikipedia:Consensus#Levels_of_consensus
# /wiki/Wikipedia:Conflict_of_interest
# /wiki/Wikipedia:Conflict_of_interest/Noticeboard
# /wiki/Wikipedia:WikiProject_Numismatics
# /wiki/Wikipedia:WikiProject_Council/Guide
# /wiki/Wikipedia:WikiProject_Council
# /wiki/Wikipedia:Shortcut
# /wiki/Wikipedia:Keyboard_shortcuts
# /wiki/Wikipedia:WikiProject_Kansas
# /wiki/Wikipedia:WikiProject_Council/Directory
# /wiki/Wikipedia:Community_portal
# /wiki/Wikipedia:Dashboard
# /wiki/Wikipedia:Department_directory
# /wiki/Wikipedia:Directory
# /wiki/Wikipedia:DIRECTORY
# /wiki/Wikipedia:Notability
# /wiki/Wikipedia:NPOV
# /wiki/Wikipedia:Describing_points_of_view
# /wiki/Wikipedia:NOTOPINION
# /wiki/Wikipedia:Glossary
# /wiki/Wikipedia:Wikipedia_abbreviations
# /wiki/Wikipedia:Manual_of_Style/Abbreviations
# /wiki/Wikipedia:List_of_shortcuts
# /wiki/Wikipedia:About
# /wiki/Wikipedia:Five_pillars
# /wiki/File:Encyclopedia_icon.svg
# /wiki/User:Afents/sandbox
# /wiki/User:Afents
# /wiki/Special:MyTalk
# /wiki/Case_sensitivity
# /wiki/String_(computer_science)
# /wiki/String_(disambiguation)
# /wiki/String_(structure)
# /wiki/Structure
# /wiki/Structure_(disambiguation)
# /wiki/Architectural_structure
# /wiki/File:20071123_Ratner_Center.jpg
# /wiki/Ratner_Center
# /wiki/Wikipedia:Good_articles
# /wiki/Wikipedia:Good_article_criteria
# /wiki/Wikipedia:Good_article_nominations
# /wiki/Wikipedia:WikiProject_Good_articles/GAN_Backlog_Drives/September_2019
# /wiki/Wikipedia:WikiProject_Good_articles
# /wiki/Wikipedia:Good_article_nominations#Media_and_drama
# /wiki/Wikipedia_talk:Good_article_nominations
# /wiki/Wikipedia:Good_article_nominations/Instructions
# /wiki/Wikipedia:Good_article_reassessment
# /wiki/Wikipedia:Good_article_nominations/Report
# /wiki/Wikipedia:Good_article_help
# /wiki/Wikipedia_talk:GAN
# /wiki/File:GA_candidate.svg
# /wiki/File:Symbol_support_vote.svg
# /wiki/Wikipedia:Criteria_for_speedy_deletion#F8
# /wiki/Help:Edit_summary
# /wiki/Help:Minor_edit
# /wiki/Wikipedia:WikiProject_Maine
# /wiki/Template:WikiProject_status
# /wiki/Template:WikiProject_status/doc
# /wiki/Help:Reverting#Undo
# /wiki/Help:Undo
# /wiki/Wikipedia:BLOCK
# /wiki/Help:I_have_been_blocked
# /wiki/Wikipedia:Blocking_policy#Evasion_and_enforcement
# /wiki/Wikipedia:Appealing_a_block
# /wiki/Wikipedia:Article_alerts
# /wiki/Template:Article_Alerts_Navheader
# /wiki/Template_talk:Article_Alerts_Navheader
# /wiki/File:WikiProject_Council_with_transparent_background.svg
# /wiki/Special:WhatLinksHere/File:WikiProject_Council_with_transparent_background.svg
# /wiki/Talk:Atlas_Shrugged
# /wiki/File:C%C3%ADrculos_Conc%C3%A9ntricos.svg
# /wiki/Special:WhatLinksHere/File:C%C3%ADrculos_Conc%C3%A9ntricos.svg
# /wiki/Talk:Algeria
# /wiki/Algeria
# /wiki/Arabic_language
# /wiki/Wikipedia:Protection_policy#pending
# /wiki/Wikipedia:WikiProject_Protected_areas
# /wiki/File:Roseberry_topping_north_side.jpg
# /wiki/Roseberry_Topping
# /wiki/Summit
# /wiki/Summit_(meeting)
# /wiki/Head_of_state
# /wiki/Head_of_government
# /wiki/Help:Introduction_to_referencing_with_Wiki_Markup/1
# /wiki/Help:Introduction_to_referencing_with_Wiki_Markup
# /wiki/File:Markup-logo.svg
# /wiki/User:Sara9mm1
# /wiki/Help:Getting_started
# /wiki/Wikipedia:Welcoming_committee/Welcome_to_Wikipedia
# /wiki/Wikipedia:Welcoming_committee
# /wiki/Wikipedia:WikiCup
# /wiki/File:Trophy.png
# /wiki/File:Trophy.jpg
# /wiki/2008%E2%80%9309_Cypriot_Cup_for_lower_divisions
# /wiki/Cypriot_Cup_for_lower_divisions
# /wiki/Help:Maintenance_template_removal
# /wiki/Wikipedia:Responsible_tagging
# /wiki/Wikipedia:Tags
# /wiki/Wikipedia:File_copyright_tags
# /wiki/Wikipedia:WikiProject_Spoken_Wikipedia/Uploading_guidelines
# /wiki/Wikipedia:WikiProject_Spoken_Wikipedia
# /wiki/Wikipedia:WIKISPEAK
# /wiki/Humour
# /wiki/Wikipedia:Pending_changes
# /wiki/Wikipedia:PCR
# /wiki/Wikipedia:TBAN
# /wiki/Wikipedia:Spam_blacklist
# /wiki/Wikipedia:Spam-blacklist
# /wiki/Wikipedia:Spam-blacklisting
# /wiki/MediaWiki:Spam-blacklist
# /wiki/MediaWiki_talk:Spam-blacklist/log
# /wiki/MediaWiki_talk:Spam-blacklist
# /wiki/Wikipedia:Request_directory
# /wiki/Wikipedia:Maintenance
# /wiki/Wikipedia:Task_Center
# /wiki/Wikipedia:Community_portal/Opentask
# /wiki/Wikipedia:Backlog
# /wiki/Wikipedia:Database_reports
# /wiki/Special:SpecialPages
# /wiki/Help:Special_page
# /wiki/Wikipedia:What_Wikipedia_is_not#Wikipedia_is_not_a_crystal_ball
# /wiki/Wikipedia:What_%22Ignore_all_rules%22_means#Use_common_sense
# /wiki/Wikipedia:Ignore_all_rules
# /wiki/Wikipedia:Consensus
# /wiki/Help:Edit_conflict
# /wiki/Wikipedia:Edit_warring
# /wiki/Wikipedia:Administrators#Wheel_war
# /wiki/Wikipedia_administrators
# /wiki/Wikipedia:Administrators
# /wiki/Wikipedia:Administration
# /wiki/Management
# /wiki/Management_(disambiguation)
# /wiki/MGMT
# /wiki/O-6-methylguanine-DNA_methyltransferase
# /wiki/Protein_Data_Bank
# /wiki/File:Wwpdb-logo.png
# /wiki/Worldwide_Protein_Data_Bank
# /wiki/Protein_structure
# /wiki/File:Protein_structure_(full).png
# /wiki/Biomolecular_structure
# /wiki/Wikipedia:Vagueness
# /wiki/Wikipedia:Essays
# /wiki/Wikipedia:NOTESSAY
# /wiki/Wikipedia:Core_content_policies
# /wiki/Wikipedia:Neutral_point_of_view
# /wiki/Wikipedia:Neutral_point_of_view/Noticeboard
# /wiki/Category:Wikipedia_backlog
# /wiki/Category:Wikipedia_administration
# /wiki/Wikipedia:Categorization#Non-article_and_maintenance_categories
# /wiki/Wikipedia:HotCat
# /wiki/Wikipedia:Blocking_policy
# /wiki/Wikipedia:Enforcement
# /wiki/Wikipedia:List_of_policies_and_guidelines
# /wiki/Wikipedia:Discord
# /wiki/Wikipedia:IRC
# /wiki/Wikipedia:FORUM
# /wiki/Wikipedia:No_original_research
# /wiki/Wikipedia:WikiProject_Norway
# /wiki/Norway
# /wiki/Norway_(disambiguation)
# /wiki/Norway,_Toronto
# /wiki/Wikipedia:What_Wikipedia_is_not#Wikipedia_is_not_a_publisher_of_original_thought
# /wiki/Wikipedia:Content_policies
# /wiki/Wikipedia:Policies_and_guidelines#Conflicts_between_advice_pages
# /wiki/Wikipedia:Principles
# /wiki/English_Wikipedia
# /wiki/File:Wikipedia-logo-v2-en.svg
# /wiki/Special:WhatLinksHere/File:Wikipedia-logo-v2-en.svg
# /wiki/Wikipedia:Slogans
# /wiki/File:Wikipedia-logo-v2-ab.svg
# /wiki/List_of_Wikipedias
# /wiki/File:Www.wikipedia.org_screenshot_2018.png
# /wiki/Webserver_directory_index
# /wiki/Wikipedia:Citing_sources#Inline_citations
# /wiki/Help:Footnotes
# /wiki/Wikipedia:Citing_sources
# /wiki/Wikipedia:Inline_citation
# /wiki/Wikipedia:Avoid_instruction_creep
# /wiki/Wikipedia:Article_creep
# /wiki/Wikipedia:CREEP
# /wiki/Wikipedia:Avoid_template_creep
# /wiki/KISS_principle
# /wiki/Kiss_(disambiguation)
# /wiki/Kiss
# /wiki/Kiss_(band)
# /wiki/Kiss_(disambiguation)#Music
# /wiki/Kiss_(comics)
# /wiki/Comic_books
# /wiki/Comics
# /wiki/Comic_(disambiguation)
# /wiki/Wikipedia:CMOS
# /wiki/Wikipedia_talk:Manual_of_Style/Comics
# /wiki/Wikipedia_talk:Manual_of_Style
# /wiki/Wikipedia:Signatures
# /wiki/Wikipedia:Wikipedia_Signpost
# /wiki/Wikipedia:Wikipedia_Signpost/2019-08-30/News_and_notes
# /wiki/Wikipedia:Wikipedia_Signpost/2019-08-30
# /wiki/Wikipedia:Wikipedia_Signpost/2019-08-30/In_focus
# /wiki/Wikipedia:Wikipedia_Signpost/Archives/2019-08-30
# /wiki/Wikipedia:Wikipedia_Signpost/Archives
# /wiki/Wikipedia_talk:Wikipedia_Signpost
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Suggestions
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom
# /wiki/Wikipedia:Wikipedia_Signpost/About
# /wiki/Wikipedia:Wikipedia_Signpost/Archives/Years
# /wiki/Wikipedia:Wikipedia_Signpost/Subscribe
# /wiki/Wikipedia_talk:Wikipedia_Signpost/Newsroom
# /wiki/Wikipedia:Wikipedia_Signpost/Next_issue
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom#Article_status
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Submissions
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Coordination
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Quick_Start
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Content_guidance
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Formatting
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Formatting/Cheatsheet
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Content_guidance#How_to_contribute
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Resources
# /wiki/Wikipedia:Wikipedia_Signpost/Newsroom/Style
# /wiki/Wikipedia:List_of_newsletters
# /wiki/Template_talk:Newsletters
# /wiki/Wikipedia:WikiProject_Wikipedia
# /wiki/File:Wikipedia-logo-v2.svg
# /wiki/Category:Wikipedia_files_on_Wikimedia_Commons
# /wiki/Category:Wikipedia_files_with_unknown_source
# /wiki/Category:Hidden_categories
# /wiki/Wikipedia:What_is_an_article%3F
# /wiki/Wikipedia:Naming_conventions_(definite_or_indefinite_article_at_beginning_of_name)
# /wiki/Category:Wikipedia_naming_conventions
# /wiki/Category:Naming_conventions
# /wiki/Help:Categories
# /wiki/Wikipedia:FAQ/Readers
# /wiki/Wikipedia:FAQ
# /wiki/Wikipedia:Contributing_to_Wikipedia
# /wiki/Wikipedia:Tips
# /wiki/Help:Menu
# /wiki/Wikipedia:Directories_and_indexes
# /wiki/Wikipedia:Indexes
# /wiki/Wikipedia:Stand-alone_list
# /wiki/Wikipedia:Manual_of_Style/Lists
# /wiki/Wikipedia:Lists
# /wiki/Help:List
# /wiki/Recipe
# /wiki/Semiconductor_fabrication
# /wiki/File:4-fach-NAND-C10.JPG
# /wiki/1.5_%C2%B5m_process
# /wiki/Semiconductor_device_fabrication
# /wiki/10_%C2%B5m_process
# /wiki/6_%C2%B5m_process
# /wiki/3_%C2%B5m_process
# /wiki/1_%C2%B5m_process
# /wiki/800_nanometer
# /wiki/Wikipedia:Verifiability#Burden_of_evidence
# /wiki/Wikipedia:VD
# /wiki/Wikipedia:Administrator_intervention_against_vandalism
# /wiki/Wikipedia:Administrator_intervention_against_vandalism/Administrator_instructions
# /wiki/Template:Uw-aiv
# /wiki/File:Information.svg
# /wiki/File:Information.png
# /wiki/File:Nuvola_apps_important.svg
# /wiki/Wikipedia:FFD
# /wiki/Wikipedia:Categories_for_discussion
# /wiki/Wikipedia:Articles_for_creation/Categories
# /wiki/Wikipedia:Articles_for_creation
# /wiki/Wikipedia:WikiProject_Articles_for_creation
# /wiki/Wikipedia_talk:WikiProject_Articles_for_creation
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Submissions
# /wiki/Category:Pending_AfC_submissions
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Submissions/List
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Showcase
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Assessment
# /wiki/Wikipedia:WikiProject_Articles_for_creation/Participants
# /wiki/Wikipedia_talk:WikiProject_Articles_for_creation/Participants
# /wiki/Wikipedia_talk:WikiProject_Articles_for_creation/Participants/Old_Requests
# /wiki/User:Nafsadh
# /wiki/File:Wikimedia_Foundation_RGB_logo_with_text.svg
# /wiki/User:Neolux
# /wiki/Website#mirror_site
# /wiki/List_of_Internet_top-level_domains
# /wiki/Talk:List_of_Internet_top-level_domains
# /wiki/Wikipedia:WikiProject_Computing
# /wiki/Wikipedia:COMPANY
# /wiki/Wikipedia:WikiProject_Organizations
# /wiki/File:Fairytale_browser.png
# /wiki/Special:WhatLinksHere/File:Fairytale_browser.png
# /wiki/Talk:Delian_League
# /wiki/Wikipedia:Vital_articles/Level/4/History
# /wiki/Wikipedia:Vital_articles
# /wiki/Wikipedia:VA
# /wiki/Wikipedia:WikiProject_Visual_arts
# /wiki/File:WPVA-khamsa.svg
# /wiki/File:WPVA-khamsa.png
# /wiki/Culture_of_Tunisia
# /wiki/File:Beit_Hikma_Tunis.JPG
# /wiki/List_of_Arabic_language_academies
# /wiki/Tunis
# /wiki/Tunis_(disambiguation)
# /wiki/Tunisia
# /wiki/French_language
# /wiki/Francophonie
# /wiki/Organisation_internationale_de_la_Francophonie
# /wiki/File:Flag_of_La_Francophonie.svg
# /wiki/La_Francophonie
# /wiki/Anthem_of_Europe
# /wiki/Ode_to_Joy
# /wiki/Symphony_No._9_(Beethoven)
# /wiki/Ludwig_van_Beethoven
# /wiki/Beethoven_(disambiguation)
# /wiki/Beethoven_(crater)
# /wiki/File:Beethoven_crater.png
# /wiki/Special:MyContributions
# /wiki/Help:User_contributions
# /wiki/Wikipedia:Namespace
# /wiki/Wikipedia:WikiProject_Nova_Scotia
# /wiki/Nova_Scotia
# /wiki/Nova_Scotia_(disambiguation)
# /wiki/Nova_Scotia,_history
# /wiki/Military_history_of_Nova_Scotia
# /wiki/Category:Military_history_of_Nova_Scotia
# /wiki/Category:Canadian_Forces_bases_in_Nova_Scotia
# /wiki/Wikipedia:FAQ/Categorization#Why_might_a_category_list_not_be_up_to_date?
# /wiki/Help:Contents
# /wiki/Help:Directory
# /wiki/Help:Cheatsheet
# /wiki/Wikipedia:Questions
# /wiki/Wikipedia:Help_desk
# /wiki/Wikipedia:Reference_desk
# /wiki/Wikipedia:The_Wikipedia_Library
# /wiki/Wikipedia:WikiProject_Libraries
# /wiki/Wikipedia_talk:WikiProject_Libraries
# /wiki/Wikipedia:WikiProject_Libraries/Introduction
# /wiki/Wikipedia_talk:WikiProject_Libraries/Introduction
# /wiki/Wikipedia:WikiProject_Libraries/Members
# /wiki/Wikipedia_talk:WikiProject_Libraries/Members
# /wiki/Wikipedia:WikiProject_Libraries/Resources
# /wiki/Wikipedia_talk:WikiProject_Libraries/Resources
# /wiki/Wikipedia:WikiProject_Libraries/Assessment
# /wiki/Wikipedia_talk:WikiProject_Libraries/Assessment
# /wiki/Wikipedia:Civility
# /wiki/Wikipedia:WikiProject_Cooperation
# /wiki/Wikipedia:Co-op
# /wiki/Wikipedia:HISPAGES
# /wiki/Wikipedia:WikipediaSpace
# /wiki/File:WikipediaSpace-WS1-Introduction-v1.pdf
# /wiki/Main_Page
# /wiki/Free_content
# /wiki/Wikipedia:Free_content
# /wiki/Wikipedia:Wikipedia_is_free_content
# /wiki/Wikipedia:Copyright_violations
# /wiki/Wikipedia:Courtesy_vanishing
# /wiki/MOS:RTL
# /wiki/Help:Wiki_markup
# /wiki/Wikitext
# /wiki/File:En-Wiki2.ogg
# /wiki/User:Dmcdevit
# /wiki/National_Archives_and_Records_Administration
# /wiki/National_Alien_Registration_Authority
# /wiki/File:State_emblem_of_Pakistan.svg
# /wiki/Special:WhatLinksHere/File:State_emblem_of_Pakistan.svg
# /wiki/Aga_Khan_III
# /wiki/File:HH_the_AGA_KHAN_1936.jpg
# /wiki/File:CC_some_rights_reserved.svg
# /wiki/File:Commons-logo.svg
# /wiki/Wikipedia:Copyrights
# /wiki/Wikipedia:WikiProject_Countries
# /wiki/Wikipedia:WPCleaner
# /wiki/File:Nuvola_web_broom.svg
# /wiki/File:Emblem-web.svg
# /wiki/GNOME
# /wiki/Gnome_(disambiguation)
# /wiki/Wikipedia:WikiGnome
# /wiki/Wikipedia:WikiProject_Linux
# /wiki/MOS:LINUX
# /wiki/Wikipedia_talk:Manual_of_Style/Computing
# /wiki/File:Commons-emblem-hand-orange.svg
# /wiki/File:Commons-emblem-hand.svg
# /wiki/File:Stop_hand_nuvola.svg
# /wiki/File:Stop2.png
# /wiki/File:Stop_hand.svg
# /wiki/File:Heckert_GNU_white.svg
# /wiki/GNU
# /wiki/Wildebeest
# /wiki/Wildebeest_(disambiguation)
# /wiki/Vickers_Vildebeest
# /wiki/File:Vickers_Vildebeest_in_flight.jpg
# /wiki/Biplane
# /wiki/Tandem_wing
# /wiki/Canard_(aeronautics)
# /wiki/File:Saab_AJS-37_Viggen_37098_52_(SE-DXN)_(9256079273).jpg
# /wiki/User:High_Contrast
# /wiki/File:Qasr_Kharana_in_Jordan.jpg
# /wiki/Wikipedia:Featured_pictures
# /wiki/Wikipedia:Flagged_protection
# /wiki/Wikipedia:PRESS
# /wiki/Wikipedia:Press_coverage_2001
# /wiki/Wikipedia:Press_coverage
# /wiki/Wikipedia:Press_coverage_2002
# /wiki/Wikipedia:Press_coverage_2003
# /wiki/Wikipedia:Press_coverage_2004
# /wiki/Wikipedia:Press_coverage_2005
# /wiki/Wikipedia:Press_coverage_2006
# /wiki/Wikipedia:Press_coverage_2007
# /wiki/Wikipedia:Press_coverage_2008
# /wiki/Wikipedia:Press_coverage_2009
# /wiki/Wikipedia:Press_coverage_2010
# /wiki/Wikipedia:Press_coverage_2011
# /wiki/Wikipedia:Press_coverage_2012
# /wiki/Wikipedia:Press_coverage_2013
# /wiki/Wikipedia:Press_coverage_2014
# /wiki/Wikipedia:Press_coverage_2015
# /wiki/Wikipedia:Press_coverage_2016
# /wiki/Wikipedia:Press_coverage_2017
# /wiki/Wikipedia:Press_coverage_2018
# /wiki/Wikipedia:Press_coverage_2019
# /wiki/Template:PressCoverageYYYY
# /wiki/Template_talk:PressCoverageYYYY
# /wiki/User:Notafish
# /wiki/Wikipedia:Wikipedia_Signpost/2019-08-30/In_the_media
# /wiki/User:Smallbones
# /wiki/Template:Wikipedia_Signpost/Templates/Navigation
# /wiki/Template_talk:Wikipedia_Signpost/Templates/Navigation
# /wiki/Wikipedia_talk:NEWSROOM
# /wiki/Help:Archiving_a_talk_page
# /wiki/Wikipedia:Historical_archive
# /wiki/Wikipedia:Historical_archive/Refreshing_brilliant_prose
# /wiki/Wikipedia_talk:Historical_archive
# /wiki/Special:Contributions/70.225.141.61
# /wiki/User_talk:70.225.141.61
# /wiki/Mario_Kart_Super_Circuit
# /wiki/File:Super_Circuit.jpg
# /wiki/Wikipedia:Non-free_use_rationale_guideline
# /wiki/Wikipedia_talk:Non-free_use_rationale_guideline
# /wiki/Wikipedia:WikiProject_Fair_use
# /wiki/Wikipedia:WikiProject_Images_and_Media
# /wiki/Wikipedia:Graphics_Lab
# /wiki/Wikipedia:Graphics_Lab/Illustration_workshop
# /wiki/Wikipedia:Graphics_Lab/Photography_workshop
# /wiki/Wikipedia:Graphics_Lab/Map_workshop
# /wiki/Wikipedia:GL/ILL
# /wiki/Wikipedia:GL/PHOTO
# /wiki/Wikipedia:GL/MAP
# /wiki/Wikipedia_talk:Graphics_Lab
# /wiki/Wikipedia_talk:Graphics_Lab/Illustration_workshop
# /wiki/Wikipedia_talk:Graphics_Lab/Photography_workshop
# /wiki/Wikipedia_talk:Graphics_Lab/Map_workshop
# /wiki/Wikipedia:GL/M
# /wiki/Wikipedia:WikiProject_Maps/Conventions
# /wiki/Wikipedia:WikiProject_Maps
# /wiki/WikiMapia
# /wiki/Talk:Wikimapia
# /wiki/Wikimapia
# /wiki/Wikipedia:BLOGS
# /wiki/Wikipedia:VECTOR
# /wiki/Wikipedia:Skin
# /wiki/MediaWiki
# /wiki/Help:MediaWiki_namespace
# /wiki/Wikipedia:Administration#Data_structure_and_development
# /wiki/Governance
# /wiki/Governance_(journal)
# /wiki/File:Governance_(journal).jpg
# /wiki/Template:Non-free_use_rationale#note-portion
# /wiki/Template:Non-free_use_rationale#note-resolution
# /wiki/Template:Non-free_use_rationale#note-purpose
# /wiki/Template:Non-free_use_rationale#note-replace
# /wiki/Template:Non-free_use_rationale#note-other
# /wiki/Template:Non-free_use_rationale/doc
# /wiki/Template:Non-free_use_rationale
# /wiki/Template:Non-free_use_rationale/sandbox
# /wiki/Wikipedia:Template_test_cases
# /wiki/Sandbox_(software_development)
# /wiki/Wikipedia:Sandbox
# /wiki/Wikipedia:About_the_Sandbox
# /wiki/Special:MyPage/sandbox
# /wiki/Special:WhatLinksHere/User:118.42.125.2/sandbox
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-12-6316f3a2e43a> in <module>
#      17                 pages.add(newPage)
#      18                 getLinks(newPage)
# ---> 19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# ...
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#      16                 print(newPage)
#      17                 pages.add(newPage)
# ---> 18                 getLinks(newPage)
#      19 getLinks("")
#
# <ipython-input-12-6316f3a2e43a> in getLinks(pageUrl)
#       6 def getLinks(pageUrl):
#       7     global pages
# ----> 8     html = urlopen("http://en.wikipedia.org"+pageUrl)
#       9     bs0bj = BeautifulSoup(html, "html.parser")
#      10     for link in bs0bj.findAll("a", href=re.compile("^(/wiki/)")):
#
# ~\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     561             http_err = 0
#     562         args = (dict, proto, meth_name) + args
# --> 563         result = self._call_chain(*args)
#     564         if result:
#     565             return result
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_302(self, req, fp, code, msg, headers)
#     753         fp.close()
#     754
# --> 755         return self.parent.open(new, timeout=req.timeout)
#     756
#     757     http_error_301 = http_error_303 = http_error_307 = http_error_302
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %% [markdown]
# ### 전체 사이트에서 데이터 수집
# - 페이지 제목, 첫 번째 문단, 편집 페이지를 가리키는 링크를 수집하는 스크레이퍼 만들기
#     * 항목 페이지든 편집 내역 페이지든 기타 무슨 페이지든 상관없이 제목은 항상 h1 태그 안에 있으며
#       h1 태그는 페이지당 하나만 존재한다.
#     * 모든 바디 텍스트는 div#bodyContent 태그에 들어 있다. 하지만 더 명확하게 첫 번째 문단의 텍스트만
#       선택하려 한다면 div#mw-content-text -> p로 첫 번째 문단 태그만 선택하는 편이 나을 수 있다.
#       이 방법은 콘텐츠 텍스트 섹션이 없는 파일 페이지를 제외한 모든 콘텐츠 페이지에 적용된다.
#     * 편집 링크는 항목 페이지에만 존재한다. 존재한다면 li#ca-edit -> span -> a로 찾을 수 있다.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

pages = set()
def getLinks(pageUrl):
    global pages
    html = urlopen("http://en.wikipedia.org"+pageUrl)
    bs0bj = BeautifulSoup(html, "html.parser")
    
    try:
        print(bs0bj.h1.get_text())
        print(bs0bj.find(id = "mw-content-text").findAll("p")[0])
        print(bs0bj.find(id = "ca-edit").find("span").find("a").attrs['href'])
    except AttributeError:
        print("This page is missing something! No worries though!")
        
    for link in bs0bj.findAll("a", href=re.compile("^(/wiki/)")):
        # /wiki/ 로 시작하는 모든 링크를 찾는다.
        if 'href' in link.attrs:
            if link.attrs['href'] not in pages:
                # 새 페이지를 발견
                newPage = link.attrs['href']
                print("----------------\n"+ newPage)
                pages.add(newPage)
                getLinks(newPage)
getLinks("")
# Out:
# Main Page
# <p><i><b><a href="/wiki/Suillus_bovinus" title="Suillus bovinus">Suillus bovinus</a></b></i>, the Jersey cow mushroom, is a <a href="/wiki/Boletaceae" title="Boletaceae">pored mushroom</a> in the family <a href="/wiki/Suillaceae" title="Suillaceae">Suillaceae</a>.  A common fungus native to Europe and Asia, it has been <a href="/wiki/Introduced_species" title="Introduced species">introduced</a> to North America and Australia. It was initially described as <i>Boletus bovinus</i> by <a href="/wiki/Carl_Linnaeus" title="Carl Linnaeus">Carl Linnaeus</a> in 1753, and given its current <a href="/wiki/Binomial_nomenclature" title="Binomial nomenclature">binomial name</a> by <a href="/wiki/Henri_Fran%C3%A7ois_Anne_de_Roussel" title="Henri François Anne de Roussel">Henri François Anne de Roussel</a> in 1806. It is an <a href="/wiki/Edible_mushroom" title="Edible mushroom">edible mushroom</a>, though not highly regarded. The fungus grows in <a href="/wiki/Pinophyta" title="Pinophyta">coniferous</a> forests in its native range, and pine <a href="/wiki/Plantation" title="Plantation">plantations</a> elsewhere. It is sometimes parasitised by the related mushroom <i><a href="/wiki/Gomphidius_roseus" title="Gomphidius roseus">Gomphidius roseus</a></i>. <i>S. bovinus</i> produces <a href="/wiki/Spore" title="Spore">spore</a>-bearing mushrooms, often in large numbers, each with a convex grey-yellow or ochre <a href="/wiki/Pileus_(mycology)" title="Pileus (mycology)">cap</a> reaching up to 10 cm (4 in) in diameter, flattening with age. As in other <a href="/wiki/Bolete" title="Bolete">boletes</a>, the cap has spore tubes extending downward from the underside, rather than <a href="/wiki/Lamella_(mycology)" title="Lamella (mycology)">gills</a>. The pore surface is yellow. The <a href="/wiki/Stipe_(mycology)" title="Stipe (mycology)">stalk</a>, more slender than those of other <i><a href="/wiki/Suillus" title="Suillus">Suillus</a></i> boletes, lacks a <a href="/wiki/Annulus_(mycology)" title="Annulus (mycology)">ring</a>. (<a href="/wiki/Suillus_bovinus" title="Suillus bovinus"><b>Full article...</b></a>)
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia
# Wikipedia
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Protection_policy#semi
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Requests_for_page_protection
# Wikipedia:Requests for page protection
# <p>This page is for requesting that a page, file or template be <b> fully protected</b>, <b>create protected</b> (<a href="/wiki/Wikipedia:Protection_policy#Creation_protection" title="Wikipedia:Protection policy">salted</a>), <b>extended confirmed protected</b>, <b>semi-protected</b>, added to <b>pending changes</b>, <b>move-protected</b>, <b>template protected</b>, <b>upload protected</b> (file-specific), or <b>unprotected</b>. Please read up on the <a href="/wiki/Wikipedia:Protection_policy" title="Wikipedia:Protection policy">protection policy</a>. Full protection is used to stop edit warring between multiple users or to prevent vandalism to <a href="/wiki/Wikipedia:High-risk_templates" title="Wikipedia:High-risk templates">high-risk templates</a>; semi-protection and pending changes are usually used only to prevent IP and new user vandalism (see the <a href="/wiki/Wikipedia:Rough_guide_to_semi-protection" title="Wikipedia:Rough guide to semi-protection">rough guide to semi-protection</a>); and move protection is used to stop <a href="/wiki/Wikipedia:Page-move_war" title="Wikipedia:Page-move war">page-move wars</a>. Extended confirmed protection is used where semi-protection has proved insufficient (see the <a href="/wiki/Wikipedia:Rough_guide_to_extended_confirmed_protection" title="Wikipedia:Rough guide to extended confirmed protection">rough guide to extended confirmed protection</a>)
# </p>
# /w/index.php?title=Wikipedia:Requests_for_page_protection&action=edit
# ----------------
# /wiki/Wikipedia:Requests_for_permissions
# Wikipedia:Requests for permissions
# <p><span class="sysop-show" id="coordinates"><a href="/wiki/Wikipedia:Requests_for_permissions/Administrator_instructions" title="Wikipedia:Requests for permissions/Administrator instructions">Administrator instructions</a></span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Protection_policy#extended
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Lists_of_protected_pages
# Wikipedia:Lists of protected pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Protection_policy
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Perennial_proposals
# Wikipedia:Perennial proposals
# <p>This is a list of things that have frequently been proposed on Wikipedia, and have been <a class="mw-redirect" href="/wiki/Wikipedia:Rejected_proposals" title="Wikipedia:Rejected proposals">rejected by the community</a> several times in the past. It should be noted that merely listing something on this page does not mean it will never happen, but that it has been discussed before and never met consensus.  <a class="mw-redirect" href="/wiki/Wikipedia:Consensus_can_change" title="Wikipedia:Consensus can change">Consensus can change</a>, and some proposals that remained on this page for a long time have finally been proposed in a way that reached consensus, but you should address rebuttals raised in the past if you make a proposal along these lines.  If you feel you would still like to do one of these proposals, then raise it at the <a href="/wiki/Wikipedia:Village_pump" title="Wikipedia:Village pump">Wikipedia:Village pump</a>.
# </p>
# /w/index.php?title=Wikipedia:Perennial_proposals&action=edit
# ----------------
# /wiki/Wikipedia:Reliable_sources/Perennial_sources
# Wikipedia:Reliable sources/Perennial sources
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Wikipedia:Reliable_sources/Perennial_sources&action=edit
# ----------------
# /wiki/Wikipedia:Reliable_sources
# Wikipedia:Reliable sources
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:RS_(disambiguation)
# Wikipedia:RS (disambiguation)
# <p>
# <b>WP:RS</b> and <b>WP:IRS</b> may refer to:
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:WikiProject_Radio_Stations
# Wikipedia:WikiProject Radio Stations
# <p>Welcome to <b>WikiProject Radio Stations</b>.  We are a <a class="mw-redirect" href="/wiki/Wikipedia:Wikiproject" title="Wikipedia:Wikiproject">group</a> dedicated to improving Wikipedia's coverage of <b><a class="mw-redirect" href="/wiki/Radio_station" title="Radio station">radio stations</a></b>.
# </p>
# /w/index.php?title=Wikipedia:WikiProject_Radio_Stations&action=edit
# ----------------
# /wiki/File:People_icon.svg
# File:People icon.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/3/37/People_icon.svg" title="People icon.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 100 × 100 pixels, file size: 22 KB)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Special:WhatLinksHere/File:People_icon.svg
# Pages that link to "File:People icon.svg"
# <p>The following pages link to <b><span id="specialDeleteTarget"><a href="/wiki/File:People_icon.svg" title="File:People icon.svg">File:People icon.svg</a></span></b>
# <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Help:What_links_here
# Help:What links here
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Project_namespace#How-to_and_information_pages
# Wikipedia:Project namespace
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Protection_policy#move
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:WPPP
# Wikipedia:WikiProject Parliamentary Procedure
# <p><b>WikiProject Parliamentary Procedure</b> is devoted to improving the quality and comprehensiveness of articles on topics related to <a href="/wiki/Parliamentary_procedure" title="Parliamentary procedure">parliamentary procedure</a>.
# </p>
# /w/index.php?title=Wikipedia:WikiProject_Parliamentary_Procedure&action=edit
# ----------------
# /wiki/File:People_icon_dead.svg
# File:People icon dead.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/6/6b/People_icon_dead.svg" title="People icon dead.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 100 × 100 pixels, file size: 24 KB)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/User:StevenDH
# User:StevenDH
# <p><br/>
# </p>
# /w/index.php?title=User:StevenDH&action=edit
# ----------------
# /wiki/Wikipedia:User_pages
# Wikipedia:User pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:FUW
# Wikipedia:File Upload Wizard
# <p>Welcome to the File Upload Wizard. This page is for uploading images and other media files to Wikipedia. When you click the link below, the wizard will guide you through a questionnaire prompting you for the appropriate copyright and sourcing information for each file. Please ensure you understand <a href="/wiki/Wikipedia:Copyrights" title="Wikipedia:Copyrights">copyright</a> and the <a href="/wiki/Wikipedia:Image_use_policy" title="Wikipedia:Image use policy">image use policy</a> before proceeding.
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Protection_policy#template
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Party_and_person
# Wikipedia:Party and person
# <p>Different content policies and guidelines use slightly different standards.  One of the commonly misunderstood distinctions is between "secondary source" and "third party".
# </p>
# /w/index.php?title=Wikipedia:Party_and_person&action=edit
# ----------------
# /wiki/File:Essay.svg
# File:Essay.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/7/7e/Essay.svg" title="Essay.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 35 × 42 pixels, file size: 17 KB)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/File:Essay.png
# File:Wikipedia Essay icon.png
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/2/2d/Wikipedia_Essay_icon.png" title="Wikipedia Essay icon.png">Wikipedia_Essay_icon.png</a> ‎<span class="fileInfo">(30 × 35 pixels, file size: 2 KB, MIME type: <span class="mime-type">image/png</span>)</span>
# </p>
# /w/index.php?title=File:Wikipedia_Essay_icon.png&action=edit
# ----------------
# /wiki/File:To_Commons.svg
# File:To Commons.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/7/78/To_Commons.svg" title="To Commons.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 913 × 913 pixels, file size: 200 KB)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Special:WhatLinksHere/File:To_Commons.svg
# Pages that link to "File:To Commons.svg"
# <p>The following pages link to <b><span id="specialDeleteTarget"><a href="/wiki/File:To_Commons.svg" title="File:To Commons.svg">File:To Commons.svg</a></span></b>
# <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/User_talk:Robert_Merkel
# User talk:Robert Merkel
# <p><a href="/wiki/User_talk:Robert_Merkel/ancient" title="User talk:Robert Merkel/ancient">User talk:Robert Merkel/ancient</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_1" title="User talk:Robert Merkel/archive 1">User talk:Robert Merkel/archive 1</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_2" title="User talk:Robert Merkel/archive 2">User talk:Robert Merkel/archive 2</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_3" title="User talk:Robert Merkel/archive 3">User talk:Robert Merkel/archive 3</a>
# <a href="/wiki/User_talk:Robert_Merkel/archive_4" title="User talk:Robert Merkel/archive 4">User talk:Robert Merkel/archive 4</a>
# </p>
# /w/index.php?title=User_talk:Robert_Merkel&action=edit
# ----------------
# /wiki/User_talk:Robert_Merkel/ancient
# User talk:Robert Merkel/ancient
# <p>Did you write the Bradman article?  If so, good work.
# </p>
# /w/index.php?title=User_talk:Robert_Merkel/ancient&action=edit
# ----------------
# /wiki/User:RjLesch
# User:RjLesch
# <p>Database developer and project manager, <a href="/wiki/Des_Moines,_Iowa" title="Des Moines, Iowa">Des Moines, Iowa</a>, <a class="mw-redirect" href="/wiki/United_States_of_America" title="United States of America">United States of America</a>.
# </p>
# /w/index.php?title=User:RjLesch&action=edit
# ----------------
# /wiki/Des_Moines,_Iowa
# Des Moines, Iowa
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Des_Moines,_Iowa&action=edit
# ----------------
# /wiki/Des_Moines_(disambiguation)
# Des Moines (disambiguation)
# <p><b><a href="/wiki/Des_Moines,_Iowa" title="Des Moines, Iowa">Des Moines</a></b> is the capital of the state of Iowa in the United States.
# </p>
# /w/index.php?title=Des_Moines_(disambiguation)&action=edit
# ----------------
# /wiki/Des_Moines_metropolitan_area
# Des Moines metropolitan area
# <p>
# <span style="font-size: small;"><span id="coordinates"><a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">Coordinates</a>: <span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=Des_Moines_metropolitan_area&amp;params=41.555147_N_93.835831_W_type:adm2nd"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">41°33′19″N</span> <span class="longitude">93°50′09″W</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">41.555147°N 93.835831°W</span><span style="display:none">﻿ / <span class="geo">41.555147; -93.835831</span></span></span></a></span></span></span>
# </p>
# /w/index.php?title=Des_Moines_metropolitan_area&action=edit
# ----------------
# /wiki/Geographic_coordinate_system
# Geographic coordinate system
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Geographic_coordinate_system&action=edit
# ----------------
# /wiki/Template:Coord
# Template:Coord
# <p>These <a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">coordinates</a> are in <a href="/wiki/Degree_(angle)" title="Degree (angle)">degrees</a>, <a class="mw-redirect" href="/wiki/Minute_of_arc" title="Minute of arc">minutes</a>, and seconds of arc.
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Template:Coord/doc
# Template:Coord/doc
# <p>These <a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">coordinates</a> are in <a href="/wiki/Degree_(angle)" title="Degree (angle)">degrees</a>, <a class="mw-redirect" href="/wiki/Minute_of_arc" title="Minute of arc">minutes</a>, and seconds of arc.
# </p>
# /w/index.php?title=Template:Coord/doc&action=edit
# ----------------
# /wiki/Wikipedia:Template_documentation
# Wikipedia:Template documentation
# <p><a href="/wiki/Help:Template" title="Help:Template">Templates</a> are a very powerful feature of <a href="/wiki/MediaWiki" title="MediaWiki">MediaWiki</a>, but can be confusing to new users and even experienced users can have difficulty making sense of the more complex ones. Templates should therefore be accompanied by <b><a href="/wiki/Documentation" title="Documentation">documentation</a></b> to improve usability.
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/File:Twemoji_1f527.svg
# File:Twemoji 1f527.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/9/9e/Twemoji_1f527.svg" title="Twemoji 1f527.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 512 × 512 pixels, file size: 1 KB)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Special:WhatLinksHere/File:Twemoji_1f527.svg
# Pages that link to "File:Twemoji 1f527.svg"
# <p>The following pages link to <b><span id="specialDeleteTarget"><a href="/wiki/File:Twemoji_1f527.svg" title="File:Twemoji 1f527.svg">File:Twemoji 1f527.svg</a></span></b>
# <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Help:Editing
# Help:Editing
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Editing_policy
# Wikipedia:Editing policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:List_of_guidelines#Editing
# Wikipedia:List of guidelines
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:List_of_policies
# Wikipedia:List of policies
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Template:Nutshell
# Template:Nutshell
# <p>This template presents a <a class="mw-redirect" href="/wiki/Wikipedia:TRITE" title="Wikipedia:TRITE">concise</a> summary at the top of  <a href="/wiki/Wikipedia:Administration#Data_structure_and_development" title="Wikipedia:Administration">administration pages</a>. It is placed below the title and other infoboxes and above the first paragraph of the main body.
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Template:Nutshell/doc
# Template:Nutshell/doc
# <p>This template presents a <a class="mw-redirect" href="/wiki/Wikipedia:TRITE" title="Wikipedia:TRITE">concise</a> summary at the top of  <a href="/wiki/Wikipedia:Administration#Data_structure_and_development" title="Wikipedia:Administration">administration pages</a>. It is placed below the title and other infoboxes and above the first paragraph of the main body.
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Subpages
# Wikipedia:Subpages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:SP_(disambiguation)
# Wikipedia:SP (disambiguation)
# <p><b><a class="mw-redirect" href="/wiki/Wikipedia:SP" title="Wikipedia:SP">Wikipedia:SP</a></b> redirects to <a href="/wiki/Wikipedia:Subpages" title="Wikipedia:Subpages">Wikipedia:Subpages</a>.
# </p>
# /w/index.php?title=Wikipedia:SP_(disambiguation)&action=edit
# ----------------
# /wiki/Wikipedia:SP
# Wikipedia:Subpages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Substitution
# Wikipedia:Substitution
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Help:Substitution
# Help:Substitution
# <p><b>Substitution</b> is a function whereby, when an editor saves a page, an item in the wikicode is permanently replaced with its current value. In particular, a <a href="/wiki/Help:Template" title="Help:Template">template</a> can be substituted, as an alternative to <a href="/wiki/Wikipedia:Transclusion" title="Wikipedia:Transclusion">transclusion</a>. The difference is that when a template is substituted on a page, its appearance on that page will no longer be affected by later changes made to the template itself (as is the case in a transcluded template).
# </p>
# /w/index.php?title=Help:Substitution&action=edit
# ----------------
# /wiki/Wikipedia:Project_namespace#Wikipedia_how-to_and_information_pages
# Wikipedia:Project namespace
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Policies_and_guidelines
# Wikipedia:Policies and guidelines
# <p><a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a> <b>policies and guidelines</b> are developed by the community to describe best practices, clarify principles, resolve conflicts, and otherwise further our goal of creating a free, reliable encyclopedia. There is no need to read any policy or guideline pages to start editing. The <a href="/wiki/Wikipedia:Five_pillars" title="Wikipedia:Five pillars">five pillars</a> are a popular summary of the most pertinent principles.
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Portal/Guidelines
# Wikipedia:Portal/Guidelines
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Portal
# Wikipedia:Portal
# <p><b>Portals</b> serve as enhanced "Main Pages" for specific broad subjects. Portals are meant primarily for readers, while encouraging them to become editors of Wikipedia by providing links to project space. Portals are created for encyclopedic topics only and not for article maintenance categories.
# </p>
# /w/index.php?title=Wikipedia:Portal&action=edit
# ----------------
# /wiki/Wikipedia:WikiProject_Portals
# Wikipedia:WikiProject Portals
# <p>Welcome to <b>WikiProject Portals</b>, dedicated to developing and maintaining <a class="mw-redirect" href="/wiki/Wikipedia:Portals" title="Wikipedia:Portals">portals</a> and portal tools. New participants are welcome; please feel free to <a href="#Project_participants">join</a>.
# </p>
# /w/index.php?title=Wikipedia:WikiProject_Portals&action=edit
# ----------------
# /wiki/Portal:Contents/Portals
# Portal:Contents/Portals
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Portal:Contents
# Portal:Contents
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Portal:Contents/Overviews
# Portal:Contents/Overviews
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Portal:Contents/Outlines
# Portal:Contents/Outlines
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Portal:Contents/Lists
# Portal:Contents/Lists
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Portal:Contents/Glossaries
# Portal:Contents/Glossaries
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Portal:Contents/Categories
# Portal:Contents/Categories
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Portal:Contents/Indices
# Portal:Contents/Indices
# <p><a class="image" href="/wiki/File:P_literature.svg"><img alt="P literature.svg" data-file-height="360" data-file-width="400" decoding="async" height="27" src="//upload.wikimedia.org/wikipedia/commons/thumb/1/1d/P_literature.svg/30px-P_literature.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/1/1d/P_literature.svg/45px-P_literature.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/1/1d/P_literature.svg/60px-P_literature.svg.png 2x" width="30"/></a> <b><a href="#General_reference">General reference</a></b><br/>
# <a class="image" href="/wiki/File:P_culture.svg"><img alt="P culture.svg" data-file-height="360" data-file-width="400" decoding="async" height="27" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/P_culture.svg/30px-P_culture.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/4f/P_culture.svg/45px-P_culture.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/4f/P_culture.svg/60px-P_culture.svg.png 2x" width="30"/></a> <b><a href="#Culture_and_the_arts">Culture and the arts</a></b><br/>
# <a class="image" href="/wiki/File:P_countries-vector.svg"><img alt="P countries-vector.svg" data-file-height="360" data-file-width="400" decoding="async" height="27" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/8e/P_countries-vector.svg/30px-P_countries-vector.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/8e/P_countries-vector.svg/45px-P_countries-vector.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/8e/P_countries-vector.svg/60px-P_countries-vector.svg.png 2x" width="30"/></a> <b><a href="#Geography_and_places">Geography and places</a></b><br/>
#  <a class="image" href="/wiki/File:P_medicine.svg"><img alt="P medicine.svg" data-file-height="360" data-file-width="400" decoding="async" height="23" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6d/P_medicine.svg/25px-P_medicine.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6d/P_medicine.svg/38px-P_medicine.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/6d/P_medicine.svg/50px-P_medicine.svg.png 2x" width="25"/></a>  <b><a href="#Health_and_fitness">Health and fitness</a></b><br/>
#  <a class="image" href="/wiki/File:Klepsydra-pt.svg"><img alt="Klepsydra-pt.svg" data-file-height="275" data-file-width="244" decoding="async" height="25" src="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Klepsydra-pt.svg/22px-Klepsydra-pt.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Klepsydra-pt.svg/33px-Klepsydra-pt.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/9/9a/Klepsydra-pt.svg/44px-Klepsydra-pt.svg.png 2x" width="22"/></a>   <b><a href="#History_and_events">History and events</a></b><br/>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Portal:Contents/Reference
# Portal:Contents/Reference
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Portal:Contents/Culture_and_the_arts
# Portal:Contents/Culture and the arts
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:CFORK
# Wikipedia:Content forking
# <p>A <b>content fork</b> is the creation of multiple separate articles (or passages within articles) all treating the same subject. Content forks that are created unintentionally result in redundant or conflicting articles and are to be avoided. On the other hand, as an article grows, editors often create <a href="/wiki/Wikipedia:Summary_style" title="Wikipedia:Summary style">summary-style</a> spin-offs or new, linked articles for related material. This is acceptable, and often encouraged, as a way of making articles clearer and easier to manage. Examples of this might be the cuisine of a particular region forking from an article about the region in general, a filmography forking from an article about an actor or director or a sub-genre of an aspect of culture such as a musical style.
# </p>
# /w/index.php?title=Wikipedia:Content_forking&action=edit
# ----------------
# /wiki/Category:Wikipedia_content_guidelines
# Category:Wikipedia content guidelines
# <p><br/></p>
# /w/index.php?title=Category:Wikipedia_content_guidelines&action=edit
# ----------------
# /wiki/Help:Category
# Help:Category
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Categorization
# Wikipedia:Categorization
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:WikiProject_Cats
# Wikipedia:WikiProject Cats
# <p>Some <a href="/wiki/Wikipedia:Wikipedians" title="Wikipedia:Wikipedians">Wikipedians</a> have formed a <a href="/wiki/Project" title="Project">project</a> to better organize information in articles related to <b><a href="/wiki/Felidae" title="Felidae">Felidae</a></b> and all varieties of <b><a href="/wiki/Cat" title="Cat">cats</a></b>.  This page and its subpages contain their suggestions; it is hoped that this project will help to focus the efforts of other Wikipedians.  If you would like to help, please add your name to the <i><a href="/wiki/Wikipedia:WikiProject_Cats#Participants" title="Wikipedia:WikiProject Cats">list of active participants</a></i> below.
# </p>
# /w/index.php?title=Wikipedia:WikiProject_Cats&action=edit
# ----------------
# /wiki/Wikipedia:CATP
# Wikipedia:WikiProject Categories
# <p><b>WikiProject Categories</b> has been set up to help manage the categories of Wikipedia and improve them.  The goal is to categorize all articles in a way that is consistent with the guidelines at <a href="/wiki/Wikipedia:Categorization" title="Wikipedia:Categorization">Wikipedia:Categorization</a>.
# </p>
# /w/index.php?title=Wikipedia:WikiProject_Categories&action=edit
# ----------------
# /wiki/Wikipedia:WikiProject
# Wikipedia:WikiProject
# <p>A <b>WikiProject</b> is a group of contributors who want to work together as a team to improve Wikipedia. These groups often focus on a specific topic area (for example, <a class="mw-redirect" href="/wiki/Wikipedia:WPMATH" title="Wikipedia:WPMATH">mathematics</a> or <a class="mw-redirect" href="/wiki/Wikipedia:INDIA" title="Wikipedia:INDIA">India</a>), a specific part of the encyclopedia (for example, <a class="mw-redirect" href="/wiki/Wikipedia:WPPORT" title="Wikipedia:WPPORT">Portals</a>), or a specific kind of task (for example, <a href="/wiki/Wikipedia:New_pages_patrol" title="Wikipedia:New pages patrol">checking newly created pages</a>). The English Wikipedia currently has over 2,000 WikiProjects, about <a href="/wiki/Wikipedia:Database_reports/WikiProject_watchers" title="Wikipedia:Database reports/WikiProject watchers">1,000 of which</a> are monitored by 30–2,000 editors and all with varying levels of activity.
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Wikimedia_sister_projects
# Wikipedia:Wikimedia sister projects
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Help:Interwikimedia_links
# Help:Interwikimedia links
# <p>An <b>interwikimedia link</b> is a <a class="mw-redirect" href="/wiki/Help:Contents/Links" title="Help:Contents/Links">link</a> from a <a href="/wiki/Wikipedia:Wikimedia_Foundation" title="Wikipedia:Wikimedia Foundation">Wikimedia Foundation</a>-supported project to another one (e.g., from <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a> to <a href="/wiki/Wiktionary" title="Wiktionary">Wiktionary</a>).
# </p>
# /w/index.php?title=Help:Interwikimedia_links&action=edit
# ----------------
# /wiki/Help:Interlanguage_links
# Help:Interlanguage links
# <p><b>Interlanguage links</b> are links from a page in one <a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a> language to an equivalent page in another language. These links can appear in two places:
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/List_of_ISO_639-1_codes
# List of ISO 639-1 codes
# <p>ISO 639 is a standardized nomenclature used to classify languages. Each language is assigned a two-letter (639-1) and three-letter (639-2 and 639-3), lowercase abbreviation, amended in later versions of the nomenclature.
# </p>
# /w/index.php?title=List_of_ISO_639-1_codes&action=edit
# ----------------
# /wiki/File:Question_book-new.svg
# File:Question book-new.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/en/9/99/Question_book-new.svg" title="Question book-new.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 512 × 399 pixels, file size: 6 KB)</span>
# </p>
# /w/index.php?title=File:Question_book-new.svg&action=edit
# ----------------
# /wiki/Wikipedia:Protection_policy#full
# Wikipedia:Protection policy
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Child_protection
# Wikipedia:Child protection
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Biographies_of_living_persons
# Wikipedia:Biographies of living persons
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Biographies_of_living_persons/Noticeboard
# Wikipedia:Biographies of living persons/Noticeboard
# <p>This page is for reporting issues regarding <b><a href="/wiki/Wikipedia:Biographies_of_living_persons" title="Wikipedia:Biographies of living persons">biographies of living persons</a></b>. Generally this means cases where editors are repeatedly adding defamatory or libelous material to articles about living people over an extended period.
# </p>
# /w/index.php?title=Wikipedia:Biographies_of_living_persons/Noticeboard&action=edit
# ----------------
# /wiki/Template:Noticeboard_links
# Template:Noticeboard links
# <p><code>{{Noticeboard links |state=uncollapsed |nostb=yes}}</code>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Template_talk:Noticeboard_links
# Template talk:Noticeboard links
# <p>The result of the move request was <b>moved to <a href="/wiki/Template:Noticeboard_links" title="Template:Noticeboard links">Template:Noticeboard links</a>.</b> –<b><a href="/wiki/User:Juliancolton" title="User:Juliancolton"><span style="font-family:Script MT;color:#36648B">Juliancolton</span></a></b> | <a href="/wiki/User_talk:Juliancolton" title="User talk:Juliancolton"><sup><span style="font-family:Verdana;color:gray"><i>Talk</i></span></sup></a> 00:21, 6 September 2009 (UTC)
# </p>
# /w/index.php?title=Template_talk:Noticeboard_links&action=edit
# ----------------
# /wiki/Wikipedia:Talk_page_guidelines
# Wikipedia:Talk page guidelines
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Help:Talk_pages
# Help:Talk pages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Help:Template
# Help:Template
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Template_messages
# Wikipedia:Template messages
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/MOS:TM
# Wikipedia:Manual of Style/Trademarks
# <p><b><a href="/wiki/Trademark" title="Trademark">Trademarks</a></b> include words and short phrases used by legal entities to identify themselves and their products and services. Often, these names are written in several ways with variations in capitalization, punctuation, and formatting. The advice in this page also applies to names and phrases used to identify individuals, movements, groups, forums, projects, events, and other non-commercial entities and their output.
# </p>
# /w/index.php?title=Wikipedia:Manual_of_Style/Trademarks&action=edit
# ----------------
# /wiki/Wikipedia:Manual_of_Style
# Wikipedia:Manual of Style
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:Policies_and_guidelines#guide
# Wikipedia:Policies and guidelines
# <p><a href="/wiki/Wikipedia" title="Wikipedia">Wikipedia</a> <b>policies and guidelines</b> are developed by the community to describe best practices, clarify principles, resolve conflicts, and otherwise further our goal of creating a free, reliable encyclopedia. There is no need to read any policy or guideline pages to start editing. The <a href="/wiki/Wikipedia:Five_pillars" title="Wikipedia:Five pillars">five pillars</a> are a popular summary of the most pertinent principles.
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia:List_of_policies#Procedural
# Wikipedia:List of policies
# <p class="mw-empty-elt">
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Wikipedia_talk:List_of_policies
# Wikipedia talk:List of policies and guidelines
# <p><span></span>
# </p>
# /w/index.php?title=Wikipedia_talk:List_of_policies_and_guidelines&action=edit
# ----------------
# /wiki/File:Peacedove.svg
# File:Peacedove.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/6/6c/Peacedove.svg" title="Peacedove.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 714 × 729 pixels, file size: 24 KB)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Special:WhatLinksHere/File:Peacedove.svg
# Pages that link to "File:Peacedove.svg"
# <p>The following pages link to <b><span id="specialDeleteTarget"><a href="/wiki/File:Peacedove.svg" title="File:Peacedove.svg">File:Peacedove.svg</a></span></b>
# <span id="specialDeleteLink"></span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Talk:Kashmir
# Talk:Kashmir
# <p>Provided the <a href="/wiki/Wikipedia:Arbitration_Committee/Discretionary_sanctions#Awareness" title="Wikipedia:Arbitration Committee/Discretionary sanctions">awareness criteria</a> are met, discretionary sanctions may be used against editors who repeatedly or seriously fail to adhere to the <a href="/wiki/Wikipedia:Five_pillars" title="Wikipedia:Five pillars">purpose of Wikipedia</a>, any expected <a href="/wiki/Wikipedia:Etiquette" title="Wikipedia:Etiquette">standards of behaviour</a>, or any <a href="/wiki/Wikipedia:List_of_policies" title="Wikipedia:List of policies">normal editorial process</a>.</p>
# /w/index.php?title=Talk:Kashmir&action=edit
# ----------------
# /wiki/Kashmir
# Kashmir
# <p>
# <span style="font-size: small;"><span id="coordinates"><a href="/wiki/Geographic_coordinate_system" title="Geographic coordinate system">Coordinates</a>: <span class="plainlinks nourlexpansion"><a class="external text" href="//tools.wmflabs.org/geohack/geohack.php?pagename=Kashmir&amp;params=34.5_N_76_E_scale:3000000"><span class="geo-nondefault"><span class="geo-dms" title="Maps, aerial photos, and other data for this location"><span class="latitude">34°30′N</span> <span class="longitude">76°00′E</span></span></span><span class="geo-multi-punct">﻿ / ﻿</span><span class="geo-default"><span class="geo-dec" title="Maps, aerial photos, and other data for this location">34.5°N 76°E</span><span style="display:none">﻿ / <span class="geo">34.5; 76</span></span></span></a></span></span></span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Kashmar
# Kashmar
# <p><b>Kashmar</b> (<a href="/wiki/Persian_language" title="Persian language">Persian</a>: <span dir="rtl" lang="fa">کاشمر</span>‎, also <a class="mw-redirect" href="/wiki/Romanize" title="Romanize">Romanized</a> as <b>Kāshmar</b>; formerly <span dir="rtl" lang="fa" title="Persian language text">ترشیز</span> <b>Torshīz</b> or <span dir="rtl" lang="fa" title="Persian language text">سلطان‌آباد</span> <b>Soltanabad</b>)<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup> is a city and the capital of <a href="/wiki/Kashmar_County" title="Kashmar County">Kashmar County</a>, in <a href="/wiki/Razavi_Khorasan_Province" title="Razavi Khorasan Province">Razavi Khorasan Province</a>, <a href="/wiki/Iran" title="Iran">Iran</a>. Cahitu is located near the river Sish Taraz in the western part of the province, and 217 kilometres (135 mi) south of the province's capital <a href="/wiki/Mashhad" title="Mashhad">Mashhad</a>, in <a href="/wiki/Iran" title="Iran">Iran</a>, from east to <a href="/wiki/Bardaskan" title="Bardaskan">Bardaskan</a>, west to <a href="/wiki/Torbat-e_Heydarieh" title="Torbat-e Heydarieh">Torbat-e Heydarieh</a>, north to <a href="/wiki/Nishapur" title="Nishapur">Nishapur</a>, south to <a href="/wiki/Gonabad" title="Gonabad">Gonabad</a>.  Until two centuries ago, this city was named <i><b>Torshiz</b></i> (<span dir="rtl" lang="fa" title="Persian language text">ترشیز</span>) and was the birthplace of <a href="/wiki/Sheikh_Ahmad-e_Jami" title="Sheikh Ahmad-e Jami">Sheikh Ahmad-e Jami</a>. At the 2006 census, its population was 81,527, in 21,947 families.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
# </p>
# /w/index.php?title=Kashmar&action=edit
# ----------------
# /wiki/Kashmar_County
# Kashmar County
# <p><b>Kashmar County</b> (<a href="/wiki/Persian_language" title="Persian language">Persian</a>: <span dir="rtl" lang="fa">Ŝahrestāne Kāŝmar</span>‎) is a <a href="/wiki/Counties_of_Iran" title="Counties of Iran">county</a> in <a href="/wiki/Razavi_Khorasan_Province" title="Razavi Khorasan Province">Razavi Khorasan Province</a> in <a href="/wiki/Iran" title="Iran">Iran</a>. The capital of the county is <a href="/wiki/Kashmar" title="Kashmar">Kashmar</a>.  At the 2006 census, its population was 146,536, in 39,554 families.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>  The county is subdivided into two districts (<a href="/wiki/Bakhsh" title="Bakhsh">bakhsh</a>): the <a href="/wiki/Central_District_(Kashmar_County)" title="Central District (Kashmar County)">Central District</a> and <a href="/wiki/Kuhsorkh_District" title="Kuhsorkh District">Kuhsorkh District</a>. The county has two cities: <a href="/wiki/Kashmar" title="Kashmar">Kashmar</a> and <a href="/wiki/Rivash,_Iran" title="Rivash, Iran">Rivash</a>.
# </p>
# /w/index.php?title=Kashmar_County&action=edit
# ----------------
# /wiki/Counties_of_Iran
# Counties of Iran
# <p>The counties of <a href="/wiki/Iran" title="Iran">Iran</a>, called <i><b>shahrestan</b></i> (<a href="/wiki/Persian_language" title="Persian language">Persian</a>: <span dir="rtl" lang="fa">شهرستان</span>‎ <i lang="fa-Latn" title="Persian-language romanization"><i>šahrestân</i></i>), are <a class="mw-redirect" href="/wiki/Administrative_divisions" title="Administrative divisions">administrative divisions</a> of larger <a href="/wiki/Provinces_of_Iran" title="Provinces of Iran">provinces</a> (<i>ostan</i>). The word <i>shahrestan</i> comes from the Persian words <i><i lang="fa-Latn" title="Persian-language romanization"><a class="extiw" href="https://en.wiktionary.org/wiki/%D8%B4%D9%87%D8%B1#Persian" title="wikt:شهر">šahr</a></i></i> ("city, town") and <i><i lang="fa-Latn" title="Persian-language romanization"><a class="mw-redirect" href="/wiki/St%C4%81n" title="Stān">stân</a></i></i> ("province, state"). "<a href="/wiki/County" title="County">County</a>", therefore, is a near equivalent to <i>shahrestan</i>.
# </p>
# /w/index.php?title=Counties_of_Iran&action=edit
# ----------------
# /wiki/File:Iran_Counties.svg
# File:Iran Counties.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/c/ce/Iran_Counties.svg" title="Iran Counties.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 1,200 × 1,071 pixels, file size: 457 KB)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/County
# County
# <p>
# A <b>county</b> is a <a class="mw-redirect" href="/wiki/Geographical_region" title="Geographical region">geographical region</a> of a <a href="/wiki/Country" title="Country">country</a> used for administrative or other purposes,<sup class="reference" id="cite_ref-chambers_1-0"><a href="#cite_note-chambers-1">[1]</a></sup> in certain modern nations. The term is derived from the <a href="/wiki/Old_French" title="Old French">Old French</a> <i>conté</i> or <i>cunté</i> denoting a <a href="/wiki/Jurisdiction_(area)" title="Jurisdiction (area)">jurisdiction</a> under the sovereignty of a <a href="/wiki/Count" title="Count">count</a> (<a href="/wiki/Earl" title="Earl">earl</a>) or a <a href="/wiki/Viscount" title="Viscount">viscount</a>.<sup class="reference" id="cite_ref-etymology_2-0"><a href="#cite_note-etymology-2">[2]</a></sup> The modern French is <i>comté</i>, and its equivalents in other languages  are <i>contea</i>, <i>contado</i>, <i>comtat</i>, <i>condado</i>, <i>Grafschaft</i>, <i>graafschap</i>, <i>Gau</i>, etc. (cf. <i><a href="/wiki/Nobility_of_Italy" title="Nobility of Italy">conte</a></i>, <i>comte</i>, <i>conde</i>, <i><a href="/wiki/Graf" title="Graf">Graf</a></i>).
# </p>
# /w/index.php?title=County&action=edit
# ----------------
# /wiki/Country
# Country
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Country&action=edit
# ----------------
# /wiki/Country_(disambiguation)
# Country (disambiguation)
# <p>A <b><a href="/wiki/Country" title="Country">country</a></b> is a geopolitical area–often synonymous with a sovereign state.
# </p>
# /w/index.php?title=Country_(disambiguation)&action=edit
# ----------------
# /wiki/Rural_area
# Rural area
# <p>In general, a <b>rural area</b> or <b>countryside</b> is a geographic area that is located outside <a href="/wiki/Town" title="Town">towns</a> and <a href="/wiki/City" title="City">cities</a>.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup> The <a href="/wiki/Health_Resources_and_Services_Administration" title="Health Resources and Services Administration">Health Resources and Services Administration</a> of the <a href="/wiki/United_States_Department_of_Health_and_Human_Services" title="United States Department of Health and Human Services">U.S. Department of Health and Human Services</a> defines the word <i>rural</i> as encompassing "...all population, housing, and territory not included within an <a href="/wiki/Urban_area" title="Urban area">urban area</a>. Whatever is not urban is considered rural."<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>
# </p>
# /w/index.php?title=Rural_area&action=edit
# ----------------
# /wiki/Rural_(disambiguation)
# Rural (disambiguation)
# <p>A <b><a class="mw-redirect" href="/wiki/Rural" title="Rural">rural</a></b> area is a geographic area that is located outside cities and towns.
# </p>
# /w/index.php?title=Rural_(disambiguation)&action=edit
# ----------------
# /wiki/Rural
# Rural area
# <p>In general, a <b>rural area</b> or <b>countryside</b> is a geographic area that is located outside <a href="/wiki/Town" title="Town">towns</a> and <a href="/wiki/City" title="City">cities</a>.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup> The <a href="/wiki/Health_Resources_and_Services_Administration" title="Health Resources and Services Administration">Health Resources and Services Administration</a> of the <a href="/wiki/United_States_Department_of_Health_and_Human_Services" title="United States Department of Health and Human Services">U.S. Department of Health and Human Services</a> defines the word <i>rural</i> as encompassing "...all population, housing, and territory not included within an <a href="/wiki/Urban_area" title="Urban area">urban area</a>. Whatever is not urban is considered rural."<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>
# </p>
# /w/index.php?title=Rural_area&action=edit
# ----------------
# /wiki/File:Barossa_Valley_South_Australia.jpg
# File:Barossa Valley South Australia.jpg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/f/f5/Barossa_Valley_South_Australia.jpg" title="Barossa Valley South Australia.jpg">Original file</a> ‎<span class="fileInfo">(3,264 × 2,448 pixels, file size: 4.21 MB, MIME type: <span class="mime-type">image/jpeg</span>)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Australian_wine
# Australian wine
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Australian_wine&action=edit
# ----------------
# /wiki/File:Australian_Wine.jpg
# File:Australian Wine.jpg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/7/76/Australian_Wine.jpg" title="Australian Wine.jpg">Original file</a> ‎<span class="fileInfo">(576 × 768 pixels, file size: 46 KB, MIME type: <span class="mime-type">image/jpeg</span>)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Canon_(company)
# Canon Inc.
# <p class="mw-empty-elt">
# </p>
# /w/index.php?title=Canon_Inc.&action=edit
# ----------------
# /wiki/File:Canon_wordmark.svg
# File:Canon wordmark.svg
# <p><a class="internal" href="//upload.wikimedia.org/wikipedia/commons/0/0a/Canon_wordmark.svg" title="Canon wordmark.svg">Original file</a> ‎<span class="fileInfo">(SVG file, nominally 800 × 168 pixels, file size: 2 KB)</span>
# </p>
# This page is missing something! No worries though!
# ----------------
# /wiki/Canon_IT_Solutions
# Canon IT Solutions
# ...
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      24                 print("----------------\n"+ newPage)
#      25                 pages.add(newPage)
# ---> 26                 getLinks(newPage)
#      27 getLinks("")
#
# <ipython-input-14-63685491f4da> in getLinks(pageUrl)
#      11     try:
#      12         print(bs0bj.h1.get_text())
# ---> 13         print(bs0bj.find(id = "mw-content-text").findAll("p")[0])
#      14         print(bs0bj.find(id = "ca-edit").find("span").find("a").attrs['href'])
#      15     except AttributeError:
#
# IndexError: list index out of range

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re
import datetime
import random

pages = set()
random.seed(datetime.datetime.now())



# 페이지에서 발견된 내부 링크를 모두 목록으로 만듭니다.
def getInternalLinks(soup, includeUrl):
    internalLinks = []
    # /로 시작하는 링크를 모두 찾습니다.
    for link in soup.findAll("a", href=re.compile("^(/|.*"+includeUrl+")")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in internalLinks:
                internalLinks.append(link.attrs['href'])
                
    return internalLinks



# 페이지에서 발견된 외부 링크를 모두 목록으로 만듭니다.
def getExternalLinks(soup, excludeUrl):
    externalLinks = []
    # 현재 URL을 포함하지 않으면서 http나 www로 시작하는 링크를 모두 찾습니다.
    for link in soup.findAll("a",
                             href=re.compile("^(http|www)((?!"+excludeUrl+").)*$")):
        if link.attrs['href'] is not None:
            if link.attrs['href'] not in externalLinks:
                externalLinks.append(link.attrs['href'])

    return externalLinks


def splitAddress(address):
    addressParts = address.replace("http://","").split("/")
    return addressParts

def getRandomExternalLink(startingPage):
    html = urlopen(startingPage)
    soup = BeautifulSoup(html, "html.parser")
    externalLinks = getExternalLinks(soup, splitAddress(startingPage)[0])
    if len(externalLinks) == 0:
        internalLinks = getInternalLinks(startingPage)
        return getNextExternalLink(internalLinks[random.randint(0,
                                                               len(internalLinks)-1)])
    else:
        return externalLinks[random.randint(0, len(externalLinks)-1)]
    
    
def followExternalOnly(startingSite):
    externalLink = getRandomExternalLink("https://www.oreilly.com")
    print("Random external link is: " + externalLink)
    followExternalOnly(externalLink)
    
# followExternalOnly("https://www.oreilly.com")

# %% [markdown]
# 사이트 전체에서 외부 링크를 검색하고 각 링크마다 메모를 남기고 싶다면 다음과 같은 함수를 추가하면 된다.

# %%
# 사이트에서 찾은 외부 URL을 모두 리스트로 수집

allExtLinks = set()
allIntLinks = set()

def getAllExternalLinks(siteUrl):
    html = urlopen(siteUrl)
    soup = BeautifulSoup(html, "html.parser")
    internalLinks = getInternalLinks(soup, splitAddress(domain)[0])
    externalLinks = getExternalLinks(soup, splitAddress(domain)[0])
    
    for link in externalLinks:
        if link not in allExtLinks:
            allExtLinks.add(link)
            print(link)
    for link in internalLinks:
        if link == "/":
            link = domain
        elif link[0:2] == "//":
            link = "http:" + link
        elif link[0:1] == "/":
            link = domain + link
            
        if link not in allIntLinks:
            print("About to get Link: "+link)
            allIntLinks.add(link)
            getAllExternalLinks(link)
            
domain = "http://www.oreilly.com"
# getAllExternalLinks(domain)
