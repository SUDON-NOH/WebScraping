# %%
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import urllib.request as REQ
import urllib
import requests
import scrapy

# Headless 모드
options = webdriver.ChromeOptions()
options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")

# UserAgent 값을 바꿔서 Headless 탐지를 막는다.
options.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36")

driver = webdriver.Chrome()

driver.implicitly_wait(5)

# 첫페이지 실행
driver.get('https://www.ncbi.nlm.nih.gov/pubmed/?term=PD1%2C+2019')

# 페이지 스크롤을 위한 변수
pagedown = 1
    
# BODY 태그를 태그이름으로 찾기
elem = driver.find_element_by_tag_name("body")

# 압묵적으로 웹 자원 로드를 위해 3초까지 기다려 준다.
driver.implicitly_wait(3)

# PMID 리스트 만들기
PMID_list = []

# requests 로 페이지 수 가져오기

url = 'https://www.ncbi.nlm.nih.gov/pubmed/?term=pd1%2C+2019'
session = requests.Session()
headers = {
    "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Connection": "close"
}
bs0bj = BeautifulSoup(session.get(url, headers = headers).content, "html.parser")
nops = bs0bj.find("h3", {"class":"page"})
nop = nops.get_text()
# print(nop)
nop = int(nop[9:])
# print(type(nop))

# %%
# print(driver.current_url)
# Out:
# https://www.ncbi.nlm.nih.gov/pubmed

# %%
"""
element 문제 발생
"""

for i in range(nop):

# =======    While 문   ==========================================================================
    # 스크롤 다운을 3번 진행
    print(i+1, '번째 스크롤 다운을 시작합니다.')
    while pagedown < 4:


        # 페이지 스크롤 타이밍을 맞추기 위해 sleep
        time.sleep(1)

        # 브라우저에 보이는 모든 dd 태그를 찾는다.
        z = driver.find_elements_by_tag_name('dd')

        for p in z:
            PMID_list.append(p.text)


#         # pagedwon을 하는 이유는 실제로 브라우저에 보이는 부분만을 추출하기 때문
#         elem.send_keys(Keys.PAGE_DOWN)

        pagedown += 1
    print(i+1, '번째 스크롤 다운을 종료합니다.')
# ========    While 문 종료 =======================================================================


    # 중복값 제거를 위해 set 후 다시 list로 전환
    PMID_list = list(set(PMID_list))
    print('PMID 의 수: ', len(PMID_list))
    
    
    # 20개씩 분류되어 있는 body에서 문제가 생기는 경우 확인
    # i = 페이지 넘버
    
#     if i != nop[-1]:
#         if len(PMID_list) % 20 != 0:
#             print('PMID의 수를 확인하세요: ', print(i))
    
    
# ==================================================================================================================
    # BODY 태그를 태그이름으로 찾기
#     elem = driver.find_element_by_tag_name("body")
    # pagedown을 초기화
    pagedown = 1
    # 페이지를 확실하게 입력하기 위해 1을 더해준다
    i = str(i + 2)
    
    # 해당 path 요소 삭제
    driver.find_element_by_xpath('//*[@id="pageno"]').clear()

    # 해당 path 요소 입력
    driver.find_element_by_xpath('//*[@id="pageno"]').send_keys(i)

    # 해당 path 에 ENTER를 직접 입력
    driver.find_element_by_xpath('//*[@id="pageno"]').send_keys(Keys.ENTER)

    driver.implicitly_wait(3)
# Out:
# 1 번째 스크롤 다운을 시작합니다.
# 1 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  20
# 2 번째 스크롤 다운을 시작합니다.
# 2 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  40
# 3 번째 스크롤 다운을 시작합니다.
# 3 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  60
# 4 번째 스크롤 다운을 시작합니다.
# 4 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  80
# 5 번째 스크롤 다운을 시작합니다.
# 5 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  100
# 6 번째 스크롤 다운을 시작합니다.
# 6 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  120
# 7 번째 스크롤 다운을 시작합니다.
# 7 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  140
# 8 번째 스크롤 다운을 시작합니다.
# 8 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  160
# 9 번째 스크롤 다운을 시작합니다.
# 9 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  180
# 10 번째 스크롤 다운을 시작합니다.
# 10 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  200
# 11 번째 스크롤 다운을 시작합니다.
# 11 번째 스크롤 다운을 종료합니다.
# PMID 의 수:  220
# 12 번째 스크롤 다운을 시작합니다.
# 12 번째 스크롤 다운을 종료합니다.
# PMID 의 수:
235619', '30741358', '31048681', '31555223', '31409885', '31732916', '31447864', '31379838', '30548881', '30541416', '31096448', '31591533', '30213523', '30542740', '31817953', '31053626', '30688989', '31776691', '30991766', '31475002', '31058839', '31218362', '31112568', '31691624', '31810958', '31745526', '31791649', '31827799', '31264180', '31751845', '31466582', '31570880', '31485666', '31192153', '30549362', '31551030', '31162838', '30939292', '31275582', '31186412', '31610223', '31796647', '31746403', '31079031', '31030234', '31432443', '30686563', '31155880', '31046743', '31849495', '31346755', '31762164', '30725359', '30500073', '30025443', '31103439', '30925913', '31047727', '31676387', '31741757', '30198439', '30867826', '30627698', '31496690', '31626860', '30723575', '31351411', '30579890', '31349094', '31385067', '31793910', '31226532', '31852716', '29548491', '31707222', '31740782', '30920211', '31085720', '30604486', '31736350', '31836816', '30598331', '30716481', '30954716', '30854842', '31488221', '31442816', '30728070', '31833607', '30539281', '30713795', '31731885', '31671149', '31293882', '31545446', '30929569', '30906656', '31665365', '31445183', '31762332', '31594104', '30713785', '30904424', '30689488', '31853575', '31537168', '31495571', '30 ...
# 569

# %%
# 새로운 주소가 필요

# for i in range(nop):

#     session = requests.Session()
#     headers = {
#         "User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit 537.36 (KHTML, like Gecko) Chrome",
#         "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
#         "Connection": "close"
#     }
#     bs0bj = BeautifulSoup(session.get(url, headers = headers).content, "html.parser")
#     PMIDs = bs0bj.find("div", {"class":"content"})
#     ID = PMIDs.find_all("dd")
#     IDs = [str(x)[4:-5] for x in ID]
    
#     for y in IDs:
#         PMID_list.append(y)
    
#     print(PMID_list)
# # ================ 페이지 이동 ===================================================================================

#     # 페이지를 확실하게 입력하기 위해 1을 더해준다
#     i = str(i + 2)
    
#     # 해당 path 요소 삭제
#     driver.find_element_by_xpath('//*[@id="pageno"]').clear()

#     # 해당 path 요소 입력
#     driver.find_element_by_xpath('//*[@id="pageno"]').send_keys(i)

#     # 해당 path 에 ENTER를 직접 입력
#     driver.find_element_by_xpath('//*[@id="pageno"]').send_keys(Keys.ENTER)

#     driver.implicitly_wait(3)
    
#     url = 'https://www.ncbi.nlm.nih.gov/pubmed'
# Out:
# ['31850687', '31850422', '31849495', '31840398', '31838340', '31836816', '31833607', '31828774', '31827799', '31823654', '31822499', '31819345', '31819174', '31817953', '31815569', '31812660', '31812347', '31811434', '31811337', '31810958']
# ['31850687', '31850422', '31849495', '31840398', '31838340', '31836816', '31833607', '31828774', '31827799', '31823654', '31822499', '31819345', '31819174', '31817953', '31815569', '31812660', '31812347', '31811434', '31811337', '31810958']
# ['31850687', '31850422', '31849495', '31840398', '31838340', '31836816', '31833607', '31828774', '31827799', '31823654', '31822499', '31819345', '31819174', '31817953', '31815569', '31812660', '31812347', '31811434', '31811337', '31810958']
# ['31850687', '31850422', '31849495', '31840398', '31838340', '31836816', '31833607', '31828774', '31827799', '31823654', '31822499', '31819345', '31819174', '31817953', '31815569', '31812660', '31812347', '31811434', '31811337', '31810958']
# From cffi callback <function _verify_callback at 0x000002083D6F6558>:
# Traceback (most recent call last):
#   File "C:\Users\SD NOH\Anaconda3\lib\site-packages\OpenSSL\SSL.py", line 306, in wrapper
#     @wraps(callback)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in do_handshake(self)
#    1914         result = _lib.SSL_do_handshake(self._ssl)
# -> 1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1646         else:
# -> 1647             _raise_current_error()
#    1648
#
# ~\Anaconda3\lib\site-packages\OpenSSL\_util.py in exception_from_error_queue(exception_type)
#      53
# ---> 54     raise exception_type(errors)
#      55
#
# Error: [('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')]
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in connect(self)
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#
# ~\Anaconda3\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     346         if HAS_SNI and server_hostname is not None:
# --> 347             return context.wrap_socket(sock, server_hostname=server_hostname)
#     348
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     461             except OpenSSL.SSL.Error as e:
# --> 462                 raise ssl.SSLError('bad handshake: %r' % e)
#     463             break
#
# SSLError: ("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~\Anaconda3\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='www.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /pubmed (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-2-d6c2905f0796> in <module>
#       7         "Connection": "close"
#       8     }
# ----> 9     bs0bj = BeautifulSoup(session.get(url, headers = headers).content, "html.parser")
#      10     PMIDs = bs0bj.find("div", {"class":"content"})
#      11     ID = PMIDs.find_all("dd")
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='www.ncbi.nlm.nih.gov', port=443): Max retries exceeded with url: /pubmed (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'tls_process_server_certificate', 'certificate verify failed')])")))
